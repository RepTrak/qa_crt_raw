# %%
import pandas as pd 
from utils.main import QA_Raw_CRT
import boto3, os
import datetime as dt
from dateutil.relativedelta import relativedelta

execution_year_month_str = '2022-12'
bucketname = 'ri-ds-crt-raw-data'
parent_dir = os.getcwd()
file_type = 'json'

# %%
qa_crt_raw = QA_Raw_CRT()

# exe_year = qa_crt_raw.cur_exe_year
# exe_month = qa_crt_raw.cur_exe_month
# pre_year = qa_crt_raw.pre_exe_year
# pre_month = qa_crt_raw.pre_exe_month

# %%
execution_year_month = dt.datetime.strptime(execution_year_month_str, '%Y-%m').date()
cur_exe_year = execution_year_month.year
cur_exe_month = execution_year_month.month

previous_execution_year_month = execution_year_month + relativedelta(months=-1)
pre_exe_year = previous_execution_year_month.year
pre_exe_month = previous_execution_year_month.month

# %%
df_cur_json = qa_crt_raw.get_data_s3(cur_exe_year, cur_exe_month, bucketname, parent_dir, file_type)

df_lst_json = qa_crt_raw.get_data_s3(pre_exe_year, pre_exe_month, bucketname, parent_dir, file_type)

# %%
df_cur_json.head()
# Out:
#    AGEGENDER  AGE_ORI  APAC_TOP1  APAC_TOP2  AP_AW1_1  AP_AW1_2 AP_AW2_1  \
# 0        NaN     11.0        NaN        NaN       NaN       NaN      NaN
# 1        NaN     10.0        NaN        NaN       NaN       NaN      NaN
# 2        NaN     13.0        NaN        NaN       NaN       NaN      NaN
# 3        NaN     10.0        NaN        NaN       NaN       NaN      NaN
# 4        NaN      4.0        NaN        NaN       NaN       NaN      NaN
#
#   AP_AW2_2  AP_AW2_99_1  AP_AW2_99_2  ...  S105Fielded_274402  \
# 0      NaN          NaN          NaN  ...                 NaN
# 1      NaN          NaN          NaN  ...                 NaN
# 2      NaN          NaN          NaN  ...                 NaN
# 3      NaN          NaN          NaN  ...                 NaN
# 4      NaN          NaN          NaN  ...                 NaN
#
#    S105Fielded_274403  S105Fielded_274404  S105Fielded_274405  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    S105Fielded_274406  S105Fielded_274408  S105Fielded_274414  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    S105Fielded_274419  SOCIALMEDIA_INF  SOCIALMEDIA_INF_A
# 0                 NaN              NaN                NaN
# 1                 NaN              NaN                NaN
# 2                 NaN              NaN                NaN
# 3                 NaN              NaN                NaN
# 4                 NaN              NaN                NaN
#
# [5 rows x 9570 columns]

# %%
df_lst_json.head()
# Out:
#    AGEGENDER  AGE_ORI  APAC_TOP1  APAC_TOP2  AP_AW1_1  AP_AW1_2 AP_AW2_1  \
# 0        NaN      NaN        NaN        NaN       NaN       NaN      NaN
# 1        NaN     11.0        NaN        NaN       NaN       NaN      NaN
# 2        NaN      NaN        NaN        NaN       NaN       NaN      NaN
# 3        NaN      5.0        NaN        NaN       NaN       NaN      NaN
# 4        NaN      NaN        NaN        NaN       NaN       NaN      NaN
#
#   AP_AW2_2  AP_AW2_99_1  AP_AW2_99_2  ...  S105Fielded_274401  \
# 0      NaN          NaN          NaN  ...                 NaN
# 1      NaN          NaN          NaN  ...                 NaN
# 2      NaN          NaN          NaN  ...                 NaN
# 3      NaN          NaN          NaN  ...                 NaN
# 4      NaN          NaN          NaN  ...                 NaN
#
#    S105Fielded_274402  S105Fielded_274403  S105Fielded_274404  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    S105Fielded_274405  S105Fielded_274406  S105Fielded_274408  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    S105Fielded_274414  SOCIALMEDIA_INF  SOCIALMEDIA_INF_A
# 0                 NaN              NaN                NaN
# 1                 NaN              NaN                NaN
# 2                 NaN              NaN                NaN
# 3                 NaN              NaN                NaN
# 4                 NaN              NaN                NaN
#
# [5 rows x 9532 columns]

# %%
new_cols_name, missing_cols_name, dict_new_uni_val, dict_missing_uni_val, df_dtype_diff, \
            df_cur_missing_val_perc = qa_crt_raw.get_compared_results_from_df(df_cur_json, df_lst_json)

# %%
new_cols_name
# Out:
# ['Q_N_32_010A_3',
#  'Q_N_3262_004A_98_other',
#  'Q_N_763_014A_1',
#  'Q_L_11700_002A_6',
#  'Q_N_11700_003A_4',
#  'Q_N_32_010A_4',
#  'Q_L_962_008_1',
#  'Q_L_11700_002_6',
#  'Q_L_11700_001_7',
#  'Q_N_32_009_1',
#  'Q_L_5636_003_6',
#  'S105Fielded_180097',
#  'S105Fielded_220044',
#  'S105Fielded_2620024',
#  'S105Fielded_1390009',
#  'S105Fielded_60571',
#  'S105Fielded_90028',
#  'Q_N_32_009_3',
#  'S105Fielded_60570',
#  'Q_OE_11700_005A_1_99',
#  'Q_N_32_007A_1',
#  'Q_L_962_008A_3',
#  'Q_N_11700_003_6',
#  'S105Fielded_60199',
#  'Q_L_962_008A_7',
#  'Q_N_32_009A_1',
#  'S105Fielded_90056',
#  'S105Fielded_180089',
#  'Q_N_11700_003A_8',
#  'Q_L_11700_002A_5',
#  'Q_N_962_007A_1',
#  'Q_L_962_008A_5',
#  'Q_N_32_010_1',
#  'Q_N_11700_004_5',
#  'S105Fielded_220045',
#  'Q_N_32_010_2',
#  'S105Fielded_1390014',
#  'S105Fielded_751019',
#  'Q_L_962_008_6',
#  'S105Fielded_2620026',
#  'S105Fielded_30915',
#  'Q_N_5240_002_1_98_other',
#  'S105Fielded_130071',
#  'Q_N_11700_004A_4',
#  'Q_L_962_008_4',
#  'Q_N_32_010_4',
#  'S105Fielded_60234',
#  'Q_N_11700_003A_7',
#  'Q_N_11700_004_1',
#  'Q_N_11700_004_4',
#  'S105Fielded_90002',
#  'Q_L_962_008_7',
#  'S105Fielded_2620022',
#  'Q_N_11700_003_8',
#  'S105Fielded_60220',
#  'S105Fielded_750327',
#  'S105Fielded_540299',
#  'Q_N_962_007_1',
#  'Q_L_962_008_11',
#  'Q_L_962_008A_6',
#  'Q_N_32_010A_1',
#  'Q_L_962_008A_10',
#  'Q_N_32_009_5',
#  'S105Fielded_1390008',
#  'Q_N_11432_007A_1',
#  'S105Fielded_1390012',
#  'Q_N_32_010A_5',
#  'Q_N_32_008A_1',
#  'S105Fielded_150158',
#  'Q_N_32_010_5',
#  'Q_N_3262_004_98_other',
#  'S105Fielded_100024',
#  'S105Fielded_151281',
#  'Q_L_11700_002_4',
#  'Q_L_11700_001A_8',
#  'Q_N_11700_003_7',
#  'Q_L_11700_001A_9',
#  'S105Fielded_100022',
#  'Q_N_962_007A_4',
#  'Q_N_11700_003A_6',
#  'Q_N_2142_005A_2',
#  'Q_L_11700_001A_7',
#  'S105Fielded_281059',
#  'Q_OE_11700_005_1_99',
#  'Q_L_5157_004A_1',
#  'S105Fielded_180098',
#  'Stakeholder_BR_BA1',
#  'S105Fielded_1390006',
#  'S105Fielded_130013',
#  'S105Fielded_220049',
#  'Q_L_962_008_9',
#  'S105Fielded_151282',
#  'S105Fielded_30914',
#  'Q_N_11700_004A_5',
#  'S105Fielded_30912',
#  'S105Fielded_1390003',
#  'S105Fielded_180105',
#  'S105Fielded_130135',
#  'Q_N_32_009A_2',
#  'S105Fielded_220041',
#  'Q_N_11700_004A_6',
#  'Q_N_11700_004A_3',
#  'Q_N_32_009A_3',
#  'Q_N_32_010A_2',
#  'Q_L_11700_002A_1',
#  'S105Fielded_100023',
#  'S105Fielded_130051',
#  'Q_N_11700_003A_3',
#  'Q_N_962_007_4',
#  'Q_L_962_008A_12',
#  'Q_N_11700_003A_5',
#  'S105Fielded_130232',
#  'Q_N_11700_003_3',
#  'Q_L_11700_002A_3',
#  'hCaptcha',
#  'Q_L_962_008A_1',
#  'S105Fielded_100025',
#  'Q_N_32_009A_5',
#  'Q_N_11700_003_2',
#  'Q_N_11827_003A_6',
#  'Q_L_32_006_1',
#  'S105Fielded_220046',
#  'S105Fielded_1390010',
#  'Q_N_962_007A_3',
#  'Q_N_11769_004A_1',
#  'S105Fielded_151283',
#  'Q_L_11700_001_9',
#  'S105Fielded_150566',
#  'S105Fielded_120136',
#  'Q_N_32_009_2',
#  'Q_L_707_006A_1',
#  'S105Fielded_90148',
#  'Q_L_11700_002A_2',
#  'S105Fielded_1390016',
#  'Q_L_32_006A_1',
#  'S105Fielded_60572',
#  'Q_L_5636_003A_6',
#  'S105Fielded_60574',
#  'S105Fielded_220038',
#  'S105Fielded_180095',
#  'Q_L_962_008_2',
#  'Q_L_962_008A_4',
#  'S105Fielded_30913',
#  'S105Fielded_90121',
#  'Q_N_11769_004_1',
#  'S105Fielded_1390015',
#  'Q_N_11700_004_2',
#  'S105Fielded_130041',
#  'S105Fielded_180094',
#  'Q_N_763_014_1',
#  'S105Fielded_130039',
#  'Q_OE_11700_005_1',
#  'S105Fielded_274033',
#  'Q_N_707_005_1',
#  'Q_N_32_009A_4',
#  'Q_L_11700_001A_11',
#  'S105Fielded_90131',
#  'Q_N_2142_005_2',
#  'S105Fielded_30916',
#  'S105Fielded_60227',
#  'S105Fielded_220042',
#  'S105Fielded_60004',
#  'Q_N_32_007_1',
#  'Q_N_5157_003_1',
#  'S105Fielded_130256',
#  'S105Fielded_60573',
#  'S105Fielded_130027',
#  'S105Fielded_1390013',
#  'S105Fielded_180096',
#  'S105Fielded_180091',
#  'Q_L_962_008_10',
#  'S105Fielded_180090',
#  'Q_N_11700_004_6',
#  'S105Fielded_130175',
#  'S105Fielded_130317',
#  'S105Fielded_1390007',
#  'S105Fielded_60569',
#  'Q_L_5157_004_1',
#  'Q_L_962_008A_8',
#  'S105Fielded_130078',
#  'S105Fielded_274419',
#  'S105Fielded_220040',
#  'Q_L_11700_001_11',
#  'S105Fielded_220039',
#  'Q_N_2142_005_1',
#  'Q_N_11827_003_6',
#  'S105Fielded_180069',
#  'S105Fielded_90149',
#  'S105Fielded_2620023',
#  'S105Fielded_750274',
#  'Q_L_11700_001A_12',
#  'S105Fielded_220048',
#  'S105Fielded_220011',
#  'Q_N_11432_007_1',
#  'S105Fielded_220047',
#  'Q_N_11700_003A_1',
#  'Q_L_11700_002_2',
#  'Q_N_11700_003_5',
#  'S105Fielded_60187',
#  'S105Fielded_90153',
#  'S105Fielded_90152',
#  'Q_L_11700_001_10',
#  'Q_L_11700_001_8',
#  'Q_N_11700_004A_2',
#  'S105Fielded_1390011',
#  'S105Fielded_1610124',
#  'Q_L_11700_001A_10',
#  'Q_L_707_006_1',
#  'Q_N_2142_005A_1',
#  'Q_L_962_008A_2',
#  'S105Fielded_750353',
#  'Stakeholder_BR_BA2',
#  'Q_L_11700_002A_4',
#  'S105Fielded_90154',
#  'Q_N_5157_003A_1',
#  'Q_L_962_008_12',
#  'Q_L_962_008_8',
#  'Q_L_962_008A_11',
#  'Q_N_11700_003_1',
#  'Q_L_11700_002_3',
#  'Q_N_11700_003A_2',
#  'Q_N_32_009_4',
#  'S105Fielded_80905',
#  'S105Fielded_220037',
#  'Q_N_962_007_5',
#  'Q_N_32_010_3',
#  'S105Fielded_90150',
#  'Q_OE_11700_005A_1',
#  'S105Fielded_60575',
#  'S105Fielded_60012',
#  'Q_L_962_008_5',
#  'Q_N_11700_004A_1',
#  'Q_N_962_007_2',
#  'Q_L_962_008_3',
#  'Q_N_11700_003_4',
#  'Q_N_962_007A_2',
#  'Q_L_11700_001_12',
#  'Q_N_962_007A_5',
#  'Q_N_32_008_1',
#  'S105Fielded_90151',
#  'Q_N_962_007_3',
#  'Q_L_11700_002_1',
#  'S105Fielded_220043',
#  'Q_L_962_008A_9',
#  'Q_N_1109_003_8_other',
#  'S105Fielded_180071',
#  'Q_N_707_005A_1',
#  'S105Fielded_180093',
#  'S105Fielded_2620025',
#  'Q_L_11700_002_5',
#  'Q_N_11700_004_3']

# %%
missing_cols_name
# Out:
# ['S105Fielded_270500',
#  'Q_L_32_002A_5',
#  'S105Fielded_260459',
#  'Q_N_962_003A',
#  'S105Fielded_260170',
#  'Q_N_707_004_2',
#  'Q_L_32_002_7',
#  'Q_L_32_003_1',
#  'S105Fielded_260272',
#  'Q_L_32_003A_1',
#  'S105Fielded_270291',
#  'Q_N_32_005A_4',
#  'S105Fielded_10590',
#  'S105Fielded_270084',
#  'Q_N_32_001A_1',
#  'Q_N_707_004A_3',
#  'S105Fielded_70002',
#  'Q_L_32_002A_10',
#  'S105Fielded_274011',
#  'Q_L_962_002A_4',
#  'S105Fielded_270037',
#  'Q_N_962_004A',
#  'S105Fielded_270027',
#  'S105Fielded_20943',
#  'S105Fielded_320760',
#  'Q_L_5636_003A_1',
#  'S105Fielded_930138',
#  'S105Fielded_320758',
#  'Q_N_32_005A_5',
#  'S105Fielded_930021',
#  'Q_L_32_002A_3',
#  'S105Fielded_151058',
#  'S105Fielded_272209',
#  'S105Fielded_120969',
#  'S105Fielded_121746',
#  'Q_L_5636_003_1',
#  'S105Fielded_270365',
#  'Q_N_32_005A_6',
#  'S105Fielded_260628',
#  'Q_L_32_002_11',
#  'Q_N_32_005A_9',
#  'S105Fielded_320056',
#  'S105Fielded_272257',
#  'Q_L_32_002_5',
#  'Q_L_32_002A_7',
#  'S105Fielded_121859',
#  'Q_L_32_002_6',
#  'S105Fielded_271378',
#  'Q_L_962_002A_3',
#  'Q_L_962_002_5',
#  'S105Fielded_270068',
#  'S105Fielded_270208',
#  'Q_N_962_004',
#  'Q_L_962_002A_1',
#  'Q_N_32_001_1',
#  'S105Fielded_1480004',
#  'S105Fielded_270855',
#  'S105Fielded_260017',
#  'Q_L_32_002A_2',
#  'Q_N_8060_001A_1',
#  'S105Fielded_70338',
#  'Q_L_32_002A_11',
#  'S105Fielded_272361',
#  'S105Fielded_270556',
#  'Q_N_32_004_1',
#  'Q_N_8060_003A_1',
#  'Q_N_32_005_3',
#  'Q_N_32_005_1',
#  'Q_L_962_002A_5',
#  'Q_N_707_004A_6',
#  'Q_N_10813_009A_98_other',
#  'Q_N_32_005A_11',
#  'S105Fielded_270352',
#  'S105Fielded_1480009',
#  'S105Fielded_272360',
#  'Q_N_32_004A_1',
#  'S105Fielded_270016',
#  'S105Fielded_270828',
#  'Q_N_32_005A_2',
#  'Q_L_32_002_1',
#  'S105Fielded_270886',
#  'Q_N_962_003A_6_other',
#  'Q_N_707_004A_2',
#  'S105Fielded_272569',
#  'Q_L_962_002_3',
#  'Q_L_32_002_3',
#  'Q_N_707_004_1',
#  'S105Fielded_270484',
#  'S105Fielded_20550',
#  'S105Fielded_272094',
#  'Q_L_32_002_2',
#  'S105Fielded_30030',
#  'S105Fielded_260619',
#  'Q_N_707_004A_98',
#  'S105Fielded_280608',
#  'S105Fielded_270145',
#  'Q_N_8060_004_1',
#  'S105Fielded_120228',
#  'Q_N_962_006A_1',
#  'S105Fielded_80010',
#  'Q_L_32_002A_12',
#  'S105Fielded_120912',
#  'Q_N_32_005A_10',
#  'Q_N_32_005_11',
#  'S105Fielded_151025',
#  'Q_N_32_005A_3',
#  'S105Fielded_273783',
#  'Q_L_32_002A_8',
#  'S105Fielded_270171',
#  'Q_N_32_005A_7',
#  'Q_L_962_002_4',
#  'Q_N_32_005A_1',
#  'S105Fielded_271057',
#  'Q_L_962_002_1',
#  'Q_L_32_002A_6',
#  'S105Fielded_272390',
#  'S105Fielded_260042',
#  'S105Fielded_10016',
#  'S105Fielded_20093',
#  'S105Fielded_2300004',
#  'Q_N_707_004_4',
#  'S105Fielded_270714',
#  'Q_N_8060_003_1',
#  'S105Fielded_270922',
#  'Q_N_707_004_6',
#  'S105Fielded_272298',
#  'Q_L_32_002A_4',
#  'S105Fielded_270380',
#  'S105Fielded_272015',
#  'Q_N_707_004_5',
#  'Q_L_962_002_2',
#  'S105Fielded_270001',
#  'S105Fielded_120905',
#  'S105Fielded_121429',
#  'Q_L_32_002_10',
#  'S105Fielded_320362',
#  'S105Fielded_270869',
#  'S105Fielded_270842',
#  'Q_L_32_002_8',
#  'Q_N_8060_001_1',
#  'S105Fielded_274192',
#  'Q_N_32_005_4',
#  'Q_L_32_002A_9',
#  'Q_N_32_005_6',
#  'S105Fielded_271523',
#  'S105Fielded_270341',
#  'Q_L_32_002_4',
#  'Q_N_32_005_10',
#  'S105Fielded_271377',
#  'S105Fielded_270154',
#  'Q_L_32_002_9',
#  'S105Fielded_30186',
#  'Q_N_962_003',
#  'S105Fielded_260547',
#  'S105Fielded_270129',
#  'Q_L_32_002_12',
#  'S105Fielded_270491',
#  'S105Fielded_270067',
#  'S105Fielded_270035',
#  'Q_N_8060_005A_1',
#  'S105Fielded_150008',
#  'Q_N_32_005_7',
#  'S105Fielded_270871',
#  'S105Fielded_270102',
#  'Q_N_32_005_9',
#  'S105Fielded_270928',
#  'S105Fielded_30863',
#  'Q_N_707_004A_4',
#  'S105Fielded_121461',
#  'Q_N_962_003_6_other',
#  'S105Fielded_260728',
#  'S105Fielded_70043',
#  'S105Fielded_272454',
#  'S105Fielded_70034',
#  'S105Fielded_270036',
#  'S105Fielded_20229',
#  'S105Fielded_20125',
#  'Q_N_707_004A_1',
#  'S105Fielded_750971',
#  'Q_N_707_004A_5',
#  'S105Fielded_271998',
#  'S105Fielded_270803',
#  'S105Fielded_260685',
#  'Q_N_8060_004A_1',
#  'S105Fielded_272445',
#  'Q_N_707_004_98',
#  'S105Fielded_273313',
#  'S105Fielded_2300031',
#  'Q_N_8060_002A_1',
#  'S105Fielded_272132',
#  'S105Fielded_30735',
#  'Q_N_32_005_5',
#  'S105Fielded_270876',
#  'Q_N_962_006_1',
#  'Q_N_32_005_2',
#  'S105Fielded_121833',
#  'S105Fielded_1480420',
#  'S105Fielded_70326',
#  'Q_L_32_002A_1',
#  'S105Fielded_272136',
#  'Q_N_8060_005_1',
#  'Q_L_962_002A_2',
#  'S105Fielded_260274',
#  'S105Fielded_273651',
#  'S105Fielded_273561',
#  'Q_N_8060_002_1',
#  'S105Fielded_270881',
#  'Q_N_32_005A_8',
#  'Q_N_707_004_3',
#  'S105Fielded_270343',
#  'S105Fielded_930029',
#  'S105Fielded_271549',
#  'Q_N_32_005_8']

# %%
dict_new_uni_val
# Out:
# {'AGE_ORI': [105.0, 110.0],
#  'AP_AW2_1': ['email re item i had on my list',
#   'There was a lot of information available from the ATO during tax time (June-October)',
#   'I have seen their tv advertising',
#   'Raising of Interest Rates.',
#   'Good and effective.',
#   'Colleague purchased new vehicle',
#   'Webex',
#   'Google found that it did not mislead users by Federl court and do not have to pay the fine',
#   'hgih quality in services',
#   "My friend's mother stays at Bupa and she says a lot of positive things about them",
#   'Movie ticket discount',
#   'Former UK health minister Therese Coffey worked for Mars early in her career; made me reflect on the kinds of people Mars has working for it.',
#   'Read an article',
#   'They are driving interest rates up and killing hard working Australians',
#   'F oh h mg hrajtstjatj',
#   'started working at ryman',
#   'YouTube advertisement',
#   'Sorry I have just seen Tesla’s around',
#   'Have seen ads about their cars and new innovations',
#   'Advertisements',
#   'Executive held in North America has been released',
#   'An advert on TV',
#   'I often visit jb hifi  and look through the computer section. My family and I spend a bit of time and money in store',
#   'Roofing and exterior products for the Australian weather conditions',
#   'Toyota having hybrid cars.',
#   "that it's one of the world's leading technology with good reason. fast and powerful internal hardware and tons of storage",
#   'one of family friends was talkin about it, i wont say exactly what due to personal reaosons but they overall had da positive view',
#   'Work colleague told me she bought her new fragrance from Mecca as it was the only store that had it in stock',
#   'Social media',
#   'My brother explained that they were a good company.',
#   'Catalogue',
#   'Advertising on social media',
#   'Their earnings fell due to Covid',
#   'Interest rates constantly rising',
#   'Criticism of case on Wikki',
#   'They offer great products',
#   'Security issues with collection of data',
#   'Cisco being on target for there zero emmission release ; annouce to train up to 6.7mil people apac',
#   'that has high interest rates on term deposit invested in Rabobank',
#   'They will be having their  Unpacked  event in February next year.',
#   'Great innovative ideas are there',
#   'puppy insurance',
#   'sddsa',
#   'Looking at the new processors',
#   'Tv adverts',
#   'New Lego sets in the shops and the new Perth Lego shop. A few ads .',
#   'The rise in interest rates.',
#   'Seen their name about on my search engine and friends talk about Ebay,',
#   'THAT THEIR SHARES HAD TAKEN A SMALL DROP',
#   'android',
#   "I've seen ads on tv",
#   'Advertising on world cup and online',
#   'It was a TV ad about a Hyndai car',
#   'I have heard that Dell is a go to for Brand for software Programmers',
#   'Cisco has handled the pandemic well.',
#   'Variety of manufacturing jobs and offers',
#   'Positive things related to the customers service',
#   'An add on the tv regarding Ingham chickens',
#   'Your life with with',
#   'I have seen ads trying to get me to purchase from their site.',
#   'They are having a 12 days of Christmas promotion where you can purchase products at a discounted price',
#   'holiday collections',
#   'Bedding and quality',
#   'Questionable data security and privacy concerns',
#   'I saw an ad for a new product.',
#   'New products for diy projects',
#   'Zespri supports local buisneses and schools providing donations to help their running',
#   'Adverts in newspapers',
#   'Mars is the good is the good is bard.',
#   'Apology for not understanding interest rate rises an the consequences of printing money',
#   'shop at ebay for chrismas',
#   'Eco friendly and effective.',
#   'search engines and software',
#   'Article about new Dell XPS laptop.',
#   'Interest rate rises and the affects it has',
#   'Just their advertising on tv',
#   'Advertisements on facebook',
#   'ghfh',
#   'I watch it monthly reports with out fail',
#   'Store in our town.',
#   'The new flip phone . Galaxy',
#   'An advertisement on TV',
#   'Vehicle ads',
#   'ongoing poor relations with developing nations and exploiting workers - poor environmental habits where other companies have overcome. Seems profits still is most important over ethical trading.',
#   'adverts in a shopping mall',
#   'it was about the purchase of Twitter',
#   'ASUS is bk passionate about technology and driven by innovation',
#   'Be you, with Bupa.  From villas and apartments to care - we have options to support your life stage.',
#   'Routers, wireless,',
#   'Something positive about good quality service',
#   'Ads on Facebook',
#   'Television and internet advertising for their Retirement living options',
#   'Laptops',
#   'shrt staff residents suffering',
#   'I’ve seen advertisements for Westfield',
#   'An add on the radio',
#   'Television Adds     Googled Patrols too look at and compare',
#   'advertising on TV',
#   'knox shopping centre starting to reopen',
#   'Not sure specifically, just advertising itself, or products I have been searching for on Google.',
#   'seen adv. on tv',
#   'great service on all things',
#   'BlueScope attempted to price-fix flat products',
#   'the show on tv',
#   'Their lack of understanding around fiscal and monetary policy. Their complete disregard for the longevity of Australia',
#   'In relation to the Adelaide 500 supercar race',
#   'Advertising products',
#   'It was just advertising',
#   'ffjhj',
#   'love',
#   'I read that in the NZ Herald business section that their earnings had dropped',
#   'Their products in store',
#   'READ THEIR NEWSLETERS,VISIT MY MOTHER AT HER BUPA UNIT AND DISCUSS PLANNED ACTIVITIESI',
#   'tv ad only',
#   'The increase in rates.',
#   'Offering eBay plus services and Cristina’s deals',
#   'Great insurance company thats offers for medical and life insrance...',
#   'Bupa resthomea  And medical alarms',
#   "New model of Kluger is a hybrid and Toyota is reportedly releasing it's hybrid version of Fortuner in Thailand next year",
#   'On T V',
#   'Add on tv',
#   'TikTok Products',
#   'Its alleged connextion with a foreign power',
#   'LOREAL ANTI DANDRUFF, GETTING RID OF DRY HAIR, REFINING IT, SMOOTH FLOWING HAIR..',
#   'They are regularly changing interest rates',
#   'To environmental issues, dumping waste in rivers.',
#   'Radio advertising for care services  Career vacancies for company across NZ',
#   'A friend bought one and I have been in it I would love to have one.',
#   "I've seen some ads when browsing Stuff or Metservice",
#   'Tv adds for fencing / roofing sheets , great add how waves turn into trimdek sheets   looks friendly and nice to the environment,  gentle approach  to change .. clever advert',
#   'They are changing their packaging',
#   'Commentary about their support for apartheid Israel and recommendations to boycott them as part of the BDS movement',
#   'Undervaluing employees.',
#   'Examples of their new products launched that includes Skincare, new perfumes and offers',
#   'Raising interest rates to combat inflation',
#   'Sports sponsorship.',
#   'Nars and meldiy',
#   'I get emails about the latest cars coming on market',
#   'About their new phone which they are releasing which has had rave reviews.',
#   'annual report',
#   'Your life with you',
#   'My daughter recently went to Costco and was amazed at the products offered',
#   'Advertising on radio, online etc',
#   'Tv add',
#   'Claims paperwork',
#   'Partnership with China/Asia to sell Kiwifruit products in their local market.',
#   'I rad that HP are laying off around 5,000 employees over the next 3 years.',
#   'they couldnt forcast to save their lives',
#   'Increasing interest rates',
#   'Just brochures that is delivered outside your home',
#   'Mainfreight has been able to endure the financial crisis.',
#   'Telstra truck',
#   'when looking for products online via google search, they always pop up with a product',
#   'They have increased the interest rate again for the third or fourth time in a row',
#   'Relating to the interest rate rising every month',
#   'Increased debt, lower profit and rise in prices for consumers',
#   'new car model',
#   'They have a lot of Westfields shopping centres across Australia & New Zealand',
#   'Adverts on TV',
#   'Reviews on Tiktok.',
#   'I have relatives is working in wooly saying Ingham is wooly’s business partner',
#   'Friends have said they brought products and where satisfied with product',
#   'How much the boss makes and wastes on space travel. Poor treatment of workers, Poor wages for workers, Anti union. Lots of overpriced products. Very expensive delivery charges',
#   'An advert',
#   'Nothing newsworthy. Just their usual advertising on TV, in-store and magazines which is quite eye catching.',
#   'I’ve seen an advertisement.',
#   "I've seen the odd TV commercial, but with most TV commercials I immediately hit the 'mute' button",
#   'TV and newspaper adds highlighting amazing activities and speakers!',
#   'fire fight',
#   'Recent article advising lay-offs will affect NC but this is to align with rebalancing resources.    There is a new products all the time. IdeaPad Gaming Chromebook which I think will be a hit for gamers with good screen resolution and game time     Also seen ads foethe thinkpad x1fold again good screen display without using up the place of a laptop or desktop',
#   'flip phone ad on tv',
#   'Bad nurses who don’t speak english',
#   'Yes my son with his NIPPIES cold drinks business uses Mainfreight for deliveries every day I worked for him in office in my younger days and Mainfreight really look after us',
#   'Email from them regarding better deposit rates',
#   'Mainly ads and emails',
#   'I watched the Lego Christmas show which is the best ad for Lego.  I loved watching this show and seeing the amazing creations.',
#   'On the tv.',
#   'Ads on YouTube about making money through Amazon and affiliation opportunities',
#   'Ads about local places that are run by bupa on the radio',
#   'New vehicles',
#   'Toyota is a world leading auto brand, heavily investing in EVs',
#   'puting uip interest rates',
#   'They are expanding largely',
#   'From a friend who has got a policy with them',
#   'Christmas  specials',
#   'it is good brand',
#   'about their products',
#   'Insurance claims tipped to soar over festive period, AMI says',
#   'The Lego Bricktmas Tv show coming up for Christmas.',
#   'They’re putting interest rates up again and just pushing families to the brink of bankruptcy to bring inflation down. It won’t work',
#   'lego master new show',
#   'Heard about rate increases and how unhappy people are',
#   'Advertising from products',
#   'I read some reviews online',
#   "They're opening a new store in Melbourne SE suburbs",
#   'can’t remember',
#   'I saw Hush Puppies being promoted on social media by an influencer. They gave away some of their products to some school teachers.',
#   'i watched a funny ad from ebay australia',
#   'I’ve seen some adds. In a building magazine I was shown and I believe they were on TV.',
#   'Advertising for their products on TV.',
#   'Opening up a new store on grafton street in Dublin Ireland. Irelands first Lego store. Attracts great crowds',
#   'on twitter, the company honoring human rights day',
#   'my friend bought a car',
#   'Pay my tax and PAYG',
#   'Insta posts',
#   'I had one with my cuppa just now ..yum',
#   'I have driven past their factory & operations in Pt Kembla recently whilst on holiday',
#   'Email',
#   'They have announced a new mother board for intel',
#   'Email communication',
#   'Advertising. Office works.',
#   'Just an ad',
#   'product',
#   'Lenovo ThinkBook 14 G2 Laptop ITL 20VD00XYVN (Core i5-1135G7 | 8GB | 256GB | Intel Iris Xe | 14 inch FHD | FreeDos | Gray)',
#   'tv advertising',
#   'the move to sustainable energy',
#   'very profitable company, good investment opportunity',
#   'aDS',
#   'They have introduce 5g',
#   "I'm not sure.",
#   'Their deals',
#   'TV show',
#   'New products     Christmas sakes',
#   'good shop',
#   'Chinese govt owned and banned from multiple countries due to govt control of tech',
#   'not paying there worker the wright money',
#   'Mostly news content surrounding Elon Musk',
#   'They are good',
#   'My insurance bill for house and contents.',
#   'Looked at the website to price new car tyres',
#   'tv ad',
#   'What they are doing re introducing EV’s to Australia',
#   'Computers are good value',
#   'THEIR ANTI ENVIRONMENTAL POLICIES IN REGARD TO WHO THEY WILL INSURE EG FOSSIL FUEL COMPANIES',
#   'Walked past a shop',
#   'Some reality show on television',
#   'TV advertising and also on social media',
#   'They were heading strong for half year results after performing very well',
#   'Very quality',
#   'Great company',
#   'I work in a Scentre Group corporation',
#   'I have seen car advertisements on the television & or in magazine/catalogues.',
#   'New line of products',
#   'Catalouge in the mail.',
#   'Billboards, online ads',
#   'sustainable packaging',
#   'it is very good',
#   'advertisement on tv and social media',
#   'on free to air tv',
#   'been reading up about their business accounts and the support they offer',
#   'Advertising their retirement village',
#   'They have provided the steel for television shows and the material which was used was very technically environmentally advanced',
#   'Need to look after your health consciously',
#   'It wasnt very nice  it was about a friend whos family member recieved poor  care',
#   'Friends purchasing various lego products',
#   "Yesterday, 6 December 2022,the Reserve Bank raised interest rates for the 8th time this year. Now the cost of living will rise more and l can't afford to pay my bills or buy groceries.",
#   "can't remember exactly as it was several months ago but it was all very positive",
#   'TV Ads',
#   'The accellerator stuck on one of their cars',
#   'Their recent philanthropic work supporting influential women',
#   'New rooms available at their Karaka site.',
#   'I receive regular marketing emails from the company.',
#   'Received emaios',
#   'I’ve seen tv advertising from Toyota',
#   'Black Friday sales & cyber Monday sales',
#   'Very well done',
#   'i saw an ad on tv for mercury energy',
#   're interest rates not rising and then doing the opposite',
#   'Advertising and report on radio, discuss with radio host',
#   'Black friday sales, christmas sales',
#   'TV ad',
#   'An article about its ethics rating',
#   'I’ve seen the tv commercials and have investigated the quality of their cars when looking to purchase a new car for our family',
#   'Higher interest rates',
#   'Not so much Tesla itself, but Elon Musk has taken over twitter',
#   'Information about a motherboard that I own',
#   'I have heard good things about the brand from people at work',
#   'All good things',
#   'It got very professional service',
#   "the product's quality is good",
#   'A friend bought a Tesla car and the person loved it',
#   'Emails with special buys',
#   "Recently i'm looking for an laptop for study and work and Lenovo is one of my top search. I do quite a lot research on some Lenovo products",
#   'Rising interest rates   greedy',
#   'products being advertised on TV',
#   'first choice platform  for retail and brand partners',
#   'A  brochure in the local newspaper',
#   'meme about the product they thought they were getting and what they actually received',
#   'they supoort the use of electric vehicles and e bikes',
#   'Heard about staff being treated unfairly.',
#   'New store opened',
#   'It was suggested when I researched for mattress protector.',
#   'Putting up interest rates',
#   'Seen the bank and heard positive reviews from friends',
#   'Emails with specials',
#   'Im sure Ive seen ads in magazine or instagram as i am familar with name. I know they do botox snd beauty treatments',
#   'They are a reputable company',
#   'something on tv',
#   'General advertising and building sites',
#   'Positive unique and informative',
#   'Adverts',
#   'I always get updated books and products',
#   'Television ad',
#   'Better online experience',
#   'A Mazda magazine advertising all their models of cars and utes',
#   'Instagram post',
#   'Car owned by a friend',
#   'They are suspected of gathering data for the government of China',
#   'I heard through the media that it is a bank having financial difficulties',
#   'I saw advertising for Christmas products',
#   'Advertising, my mother in law is working with them and only hear good and great thing. I myself have worked with them and only have positive',
#   'Amazon is wanting to cut ties with Twitch (I believe)',
#   'advertising for care facilities',
#   'i saw an advert on social media',
#   'Your life with',
#   'Christmas chair cover',
#   'New telephone',
#   'On a radio tech program the Australian CEO discussed Lenovo computers and changes to new products. Eg energy ratings',
#   'Seen new products in local stores',
#   'about available outlets for pick up of products',
#   'Insurance',
#   'Live the life that you deserve',
#   'Advertising services provided',
#   'Mainly around fuel prices',
#   'Ads on my social media & tv',
#   "Can't remember specifics, something about a new village",
#   'Just an ad on tv',
#   'Bathroom products',
#   'Television ad regarding their products',
#   'I just know they sell printers and its a brand i do like in that catergory',
#   'TV advert',
#   'Billboards on the roadside',
#   'Have heard the name come up before in conversations.',
#   'About their motor products',
#   'emails, website, TV',
#   'About their rest home vacancies',
#   'I have heard that they are very helpful and very compassionate about what they doing and want the best for there customers',
#   'Social media posts',
#   'I LIKWE BRABND',
#   "Musk's earnings from Telsa",
#   'Sales that have happened',
#   "It's annual financial report",
#   'Mainfreight making record profit over last year.',
#   "I've seen positive product reviews",
#   'Class action in regards to the HiLux',
#   'Advertising on TV',
#   'advertising on tv',
#   'Some of the people I watch online are sponsored by Lenovo and I follow them on social media',
#   'Some adds for products',
#   "Didn't realise Zespri is the largest marketer of kiwi fruit in the world.  Also that they offer 2 horticultural scholarships at Massey University.",
#   'Adverts on tv for their Tucson',
#   'Email with special offers',
#   'their laptop is fast and effecient',
#   'adds on tv',
#   'New products that were being advertised on the tv about new flavours',
#   'Saw advertising for it online',
#   'Online advertising on YouTube about care facilities',
#   'I HAVE SEEN INGHAM',
#   'Announcements in relation to interest rates and inflation',
#   'Christmas specials',
#   'It was an ad',
#   'A lot of good looking cars.',
#   'News about how the RBA got rate forecasting wrong and had to increase rates fast',
#   'A new Costco being built nearby',
#   'Chinese government owned and not to be trusted',
#   'Add on Facebook',
#   'I uses to be a small shareholder so still get regularly  updates about the company.',
#   'Working together with Qantas on promotions',
#   'Sales new products',
#   'Village advertising',
#   'Ads for Tuesday bargains',
#   'Recall of certain vehicles and collaboration with chinese company to develop and install batteries that will significantly increase distance between charging.',
#   'Their singing tv ad, with the driver hitting the garage wall',
#   'I have seen adds',
#   'Re-imagining Knox City Shopping centre',
#   'Advertising regarding the BlueScope Steel and comments on the product',
#   'they are a good company',
#   'Supported kids cancer charities',
#   'Advertising material on social media',
#   'advertisements for the mazda 3',
#   'Advertisements featuring their products',
#   'Data collection',
#   "Lego being found in the ocean, along the shore lines and on the floor of the ocean. It is case pollution I'm sure they may not be aware of.",
#   'From what I can remember, I saw numerous advertisements for new car designs/innovations most commonly on Youtube advertisement breaks.',
#   'TV commercials',
#   'About car insurance ad on social media',
#   'Only what I have been involved in with online. I am very positive about my involvement with EBay',
#   'Adds on Tv',
#   'Prices',
#   'I READ THEIR SHAREHOLDER LETTER',
#   'Advertising for Z Flip4',
#   'All good positive things',
#   'they always provide info on their products wirh creativev ads through all media',
#   "I'm sure it was online somewhere, about the facilities offered and care of residents",
#   'I get promotion emails all the time',
#   'Friend was talking to me about their experience',
#   'An advertisement for the Company on line.',
#   'Fine for director who don’t register',
#   'All  Positive reports and makes me interested in getting to know better',
#   'I just seen an ad for Costco fuel',
#   'Leaflet in local newspaper',
#   'there anueal report as i have shares in that compy',
#   'computer ad',
#   'i seen there black friday sales sent to my email box, it was on products reduced. i also seen their promotion to join their membership for $4.99 not the usual $50, in my inbox and across the ebay app.',
#   'Online website',
#   'Specials/sales',
#   'I pass by their Hastings office several times per week',
#   'I use a Dell computer and get messages from the company re products and upgrades',
#   'received dividend',
#   'Enforcement',
#   'It manufactures lego-brand toys. They have some headquarters around the world. It is one of the best lego-brand companies.',
#   "Blue scope produces termite proof building materials and won't warp or rut.",
#   'Racism in the workplace and car accidents',
#   'A matter of a pay dispute for a large number of employees',
#   'The battery life on their flip phones are not that good. But we currently and can see how the battery does not last as long as the previous Samsung phones we have owned.',
#   'look at there retirement villages',
#   'I have seen tv advertising',
#   'I have seen ads promoting Bluescope Steel.',
#   'Product range - laptop. Envy.',
#   'tv adverts',
#   'Not complying to the RBNZ',
#   'I believe it was in some sort of financial trouble',
#   'Netflix- where is my jet',
#   'advertising new servces.',
#   'Just marketing material',
#   'Add about products and prices',
#   '1tv',
#   'I receive assistance and promotional material relating to my HP printer',
#   'The owner lost a lot of money',
#   'New google phone products',
#   'I have a friend who lives in a Summerset Village. She is very happy there.',
#   'they are advertising the pepsiverse an interesting new set of commercials',
#   'Continuous interest rate increases disturbing families and loan holders',
#   'email',
#   'In the car section of the newspaper - possibly car of the year??',
#   'overcharging, contining to charge after occupants move out.gouging',
#   'Advertising about open days in leaflets inserted into the newspaper',
#   'An Instagram ad',
#   'Lego show on tv',
#   "I have seen some advertising on e-bay, can't remember where. I remember it was one of the first of it's type of retailer so has that advantage as the name/brand are well known. Problem with all on line type sales is security & hackers.",
#   'Read about new products they are releasing',
#   'Television advertising their products',
#   'email from ebay seller',
#   "Youtube, where's my jet?",
#   'Email about its new laptops and products',
#   'advertisment',
#   'post on social media new shapes and model.',
#   'advertising their retirement establishments .',
#   'Employment issues',
#   'Their amazing offers of makeup and skin products',
#   'an email regarding thier new product Hypergate Air  Level 3 Ultra',
#   'Mostly on tiktok from the followers I follow',
#   'I like watching their shows',
#   'Christmas deals',
#   'Have recently seen one of their ads on youtube where the guy clicks the skip the ad button',
#   'Advertising their services on social media',
#   'Brochures',
#   'great modern equipments',
#   'Signage out the front window for a laser promotion they were running at the time. It had special.on it',
#   'ads about their electronic sales',
#   'Just seen recent marketing when walking past the stores.',
#   'Well, I am doing this survey on a Lenovo desktop right now, and it is by far the best PC that I have had. I see an ad for it every time I switch it on.  I would stick with Lenovo, given choices.',
#   'Opening new branches near me',
#   'J B Hifi catalogues, listing special deals on Lenovo computers.',
#   'Advertising for new Hyundai model cars',
#   'so good to come true',
#   'great services',
#   'Advertisement on TV',
#   'advertisement',
#   'JUST SOME ADVERTISING ABOUT THE VARIUOS USES OF EBAY',
#   'information',
#   'About there specials on',
#   'Have seen commercials of their fitting process.',
#   'GREAT SERVICE',
#   'Have seen more Tesla dealerships appear in my local area.',
#   'Good place to shop and positive',
#   'Post on social media regarding sales during the holiday season, people paying it forward and helping thoes in need, kind and friendly staff',
#   'Regarding mortgage interest rates',
#   'Saw an ad on TV',
#   'Mainly advertising about its  new product lines, especially PCs',
#   'not sure',
#   'Toyota adds on television',
#   'Shop displays',
#   'I see their trucks going through our town daily',
#   'Think it was advertised on The Block.',
#   'neagtivity about traffic jams around their chermside shops and gangs in the area- their toilets afre filthy and in disrepair and often have no paper towel or sanitiser- they have let their stores go'],
#  'AP_AW2_2': ['About the new western Australian site being built',
#   'Upgrade of local centre',
#   'saw an ad on a tv streaming website while watching a video',
#   'Good reporta',
#   'Laptops.',
#   'I have seen an ad on tv and gone into the Nissan dealership',
#   'A television advertisement',
#   'house for sale',
#   'Sign posts of new developments',
#   'On Tv commercial',
#   'At the shops, online ads and by word of mouth',
#   'Veery ppl,Elon head phone sets',
#   'avertisement',
#   "Can't remember specifics",
#   'they are building new retirement villages',
#   'seen tv ads',
#   'TV',
#   'They were mentioned in stations promos for (I think) Channel 9.',
#   'Security of their data and encryption on mobile phones in South African politics.',
#   'An advertisement on tv about Westfield',
#   'Ads on items that I has been browsing',
#   'Personal emails sent to me about products.',
#   'Discussions regarding official interest rates',
#   'Trustworthy',
#   'ADVERTISING THE NEW MAZDA MODELS, WITH MORE ADVANTAGES.',
#   'Just advertisements',
#   'Amazon is unfair to Amazon drivers and does not care about their Amazon flex drivers.',
#   '$200 credit for joining Mercury',
#   'Television advertisements',
#   'Advertising product',
#   'online ad',
#   'Special offers',
#   'Emails and promotion sms',
#   'EMAIL',
#   'Good and reliable company',
#   'CSR activity',
#   'New technology and product',
#   'perfect in products',
#   'On facebook ive seen adds.   When in the shop they have good displays that are exciting',
#   'Products in my ema',
#   'android',
#   'Opening hours',
#   'Have either seen it via ans advertisement or from app on the phone',
#   'catalogue instore',
#   'I have seen advertising on their shop near me',
#   'Patient neglect',
#   'app Xmas competition',
#   'Offers, employment opportunities',
#   'TV and print ads',
#   'TV ads about the quality and endurance and pleasing appearance of its products.',
#   'Very reputation',
#   'Cars catching fire',
#   'I saw an ad for a new product.',
#   'That they are continuing to progress',
#   'To celebrate Fifa 2022 inviting people towards a world gor sustainability',
#   'Interest rate miscommunication',
#   'Products and options available',
#   'Tv ads. I have also purchased from them',
#   'Emails re interest rates',
#   'Advertisement on how good this is',
#   "I've seen an add on Facebook about their care facilities",
#   'Instagram ads for both general sales, specifically for Christmas, as well as ads for products I had been browsing',
#   'In regard’s to interest rates',
#   'Read about their tech products',
#   'positive progress in what they are doing',
#   'that it has pretty good villages for  reasonable prices',
#   'I vaguely remember some bad news in the press regarding this brand. I can’t remember details but I think ‘scandal’ when I think of this brand.',
#   'Advertising online, tv',
#   'That Elon musk needs to focus mote on Tesla.',
#   'My appointment time email, offers available email',
#   'Computer in JB HI-FI, promotion on black Friday',
#   'Extensive product advertising',
#   'Apart from its technological  products that it sells, I am also aware of the Kindle/ Book programs and how people are monetizing same',
#   'Their cars are a massive safety hazard to both the driver and everyone else around them.',
#   'I saw N30i new shape n model.',
#   'I have seen a documentary about legoworld.',
#   'I have an elderly cousin 90 years old in Ryman in Kamo she has been there some years now and never been happy with the staff. Some days never helped with showering had dinner brought any time up to 9.00 in the evening asian staff lack communication and personality toward her. She has complained but no extra action toward being nice to her has ever happened. Sadly she is living a life of misery.',
#   'Elon Musk is very vocal',
#   'Announcement for Westfield group and media has joined ; changes to their board',
#   'I saw an add on television.',
#   'it is good',
#   'I have had several ads in my emails - black Friday being the biggest but also ebay offering discounts on different products.',
#   'Discounts for christmas',
#   'Cisco won the top spot for best employer for 2022',
#   "Car being blown up because tesla couldn't,  wouldn't fix the problem,  lots of recalls problems etc battery life not good and cheaper to buy a new car than replace a battery pack , not saving the environment?",
#   'emails',
#   'I drive a Toyota.',
#   'seen adverts on tv',
#   'That the technology now exists to run the car from a chip in your brain',
#   'ads on tv and social media',
#   'an ad on the tv',
#   'Products theysell online',
#   'The federal court has found that Mazda engaged in misleading and deceptive conduct.',
#   'Local shopping centre has one, so I’ve seen their advertising. I’m sure I’ve seen ads on Facebook also.',
#   'I have seen positive articles on social media',
#   'When purchasing from ebay',
#   'Signs near the construction at Elmwood, Manurewa.',
#   'It develops and manufactures information technology products and services. It is a big IT company with more than 90,000 employees.',
#   'I seen a few ads',
#   'adv on TV',
#   'We have had an extended family member in their care.',
#   'Nestle chocolate cereal',
#   'Promotion of new styles of lego',
#   'Policy reminder',
#   'Emails with new products',
#   'They are related and trustworthy',
#   'Advertisement and saw the shop',
#   'fghgfh',
#   'Elton musk',
#   'Adverts about new products. Reviews regarding good quality products',
#   'Computer products are goid',
#   'Advertising in shopping centre',
#   'An advert',
#   'An ad',
#   'I have Read, Heard, and Seen Advertisements on the Radio, Television, and Paper Publications.',
#   'Lego masters tv show, advertising, lego stores',
#   'Great security and customer relations',
#   'TV commercial',
#   'Going to use new wrapping for its products',
#   'Advertising on the TV',
#   'Cars',
#   'What they have to offer',
#   'Change of eBay sale fees',
#   'Great range of products',
#   'tv advertisemtns around their trade in options at the end of a vehicle lease period',
#   'Tv adds magazine adds',
#   'Constant adverts with that green annoying cross dressing witch on tv.',
#   'just policy information',
#   'Advertisements on TV showing the latest products as well as advertisements on billboards and buses in the area',
#   'Only the emails they send about products',
#   'Advertising their new building in Manukau.',
#   'it is good brand',
#   'Increased interest rates',
#   'Blue scope steel is one of the leading steel manufacturers',
#   'One of my friends has been in one for many years and another one is moving in soon and they both speak highly of it',
#   'I’ve seen advertisements for their phones',
#   'just their tv ads',
#   'ripping off the poor merchants who use its shopping centres',
#   'Buying online',
#   'Tv ad where they drink Pepsi and coke but don’t know which it is and Pepsi was tastier',
#   'The Christmas Ads and car parts ads',
#   'I get a regular email from them advertising their latest sales',
#   'A news report that they were exiting some product lines due to unprofitability.',
#   'I think I heard something on the news. Something also did pop up at my work.',
#   'The all new Ford car',
#   'have inspected there villages for an appartment',
#   'Emails from Amazon about its products',
#   'An advertisement on TV advertising Bupa services',
#   'Products. Laptops',
#   'Adds on tv and social media marketing there products  and sales',
#   'News Releases  Double award win for IAG',
#   'A new store opening in Sorrento',
#   'that the had to recll some of there cars',
#   'Seeing more of their cars on the road',
#   'Advertising merchandise',
#   "I'm not sure.",
#   'Sales information',
#   'Advertisements on the tv/social media',
#   'Developing new products and growing',
#   'that they are building new retirement villlage somewhere',
#   'Tv and for chocolate',
#   'Researched a new phone and advertisements for both phone and TV',
#   'A new financial officer appointed',
#   'EBay plus promotion and Black Friday sales',
#   'Monthly interest situation',
#   'Advertisements at the car depot',
#   'Prime membership',
#   'some of my friends talk about the service quality of BP Australia on the social media',
#   'ad',
#   'ADVERTISMENTS',
#   'Their current vehicles',
#   'tv ad',
#   'Reports back to China not a secure phone',
#   'Seen the latest tablets for sale with their name',
#   'An email with Black Friday offers',
#   'Supports local school band',
#   'Claims Huawei products can be used to spy for the CCP',
#   'flyer for sale',
#   'Research into the actions of the Reserve Bank regarding all the interest rate rises following statements made previously that there would be no rate rises until 2024.',
#   'An advertisement for a range of pickup trucks.',
#   'Watched the Christmas Special with the Celebrities',
#   'Just tik toks advertising',
#   'bad advice re interest',
#   'An email to me about my renewal for my home insurance.',
#   'Laptop online',
#   'Bloke I work with talks about cosco',
#   'TV ad of half price sale',
#   'promotional emails etc..',
#   'TV advertising for new ranges of electric vehicles',
#   'Television,radio',
#   'I am a customer, so get info messaged',
#   'I order from them a few times a year so I have seen all the sales etc',
#   'Ryman Healthcare have had some cases of Covid recently in our own village, we being two cases in question.',
#   'Good profit',
#   'TV adds for the sale of there vehicles',
#   'TV ads i am sure. Perhaps radio  Too',
#   'world wide bans on their products for sneaky business practices re Chinese Communist Party',
#   'I have seen new products such as the Star Wars head figurines as well as some social media content relating to LEGO products',
#   'Poor treatment of employee',
#   'HP to lay off 6,000 employees',
#   'Written advertisement',
#   'Black Friday sales at JB-HiFi an Asus computer which did not quite fit in my budget.',
#   'A video of a Tesla car malfunctioning',
#   'Tech brochures offering what they can offer',
#   'So many things especially about their leader Bezos',
#   'I have seen the website',
#   'Just catalogue articles',
#   'A friend  lives in one of there units and love it',
#   'Flyers in my letterbox',
#   'I Purchased an Asus Tek gaming laptop recently and AsusTek  provide excellent software support',
#   'TV ad',
#   'Rising interest rates',
#   'Feedback from a resident',
#   "Can't remember",
#   'I was speaking to a friend who is a customer of Dell with her communication equipment. She totally reccomends Dell',
#   "Online ads but can't remember what platforms",
#   'Profitable company.',
#   'New cars and tech on cars',
#   "Advertising it's products",
#   'A newer land cruiser in dark grey and a twin cab Ute',
#   'Follow stock price',
#   'They always have new products',
#   'Adverts on tv',
#   'TV add about things you can do while you are a resident there.',
#   'A recall on a product. Spinach',
#   'New offer of its retirement village',
#   'Saw a TV advertisment',
#   'YouTube ads',
#   'The Block 2022',
#   'Car ad',
#   'An advertisement to buy their product',
#   'the way it delivers its services',
#   'I receive regular emails with product information',
#   'report',
#   'I LIKE BRAND',
#   'Na',
#   'Scentre group is the good to go.',
#   'got some emails from them',
#   'xmas giveaway',
#   'nothing good. recent rate changes.',
#   'I often see Dell products being advertised online with amazing new specs on laptops and tablets.',
#   'Different ways to bank, through advertisment',
#   'New cars on the road',
#   'I get promotional emails from Amazon recommending products',
#   'On chemist catalogues  and zxz',
#   'I have browsed in one of their stores.',
#   'New phones',
#   'New phone, new TVs',
#   'Ingham have got good specials on Turkey breasts at the moment.',
#   'Tech savvy',
#   'Positive unique and informative',
#   'It exploits employees',
#   'Negative comments',
#   'Adverts',
#   'Advertising on tv radio and social media',
#   'Television ad',
#   'My brother spoke about it - he shops there',
#   'I have read about their tablets because I have thought about buying one again',
#   'Car on tv',
#   'Increasing the interest rates',
#   'The items that eBay has to offer and how sellers can connect with shoppers',
#   'It was all about putting up intere3st rates',
#   'Papers',
#   'Xmas trading hours',
#   'They had a regulatory problem with government but I can’t recall the details.',
#   'New models/company owner in media',
#   'KKR has purchased Laser Clinic Australia',
#   'New village being built',
#   'i have watch some things about telsa and i had a short drive of a tesla car i was washing for some one',
#   'very good service great prices',
#   'brochure',
#   "I have heard mostly negative or impartial things about the company and it's products. Like how some of their products do not meet expectations or how the owner of the company makes poor choices when it comes to business decisions.",
#   "Yes. how they said interest rates would'nt rise until 2024 and instead they have risen on multiple  each month",
#   'They are using new environment packaging',
#   'Plans for development of Westfield Parramatta',
#   'Trucking jobs aswell as the products they always transporting around the beautiful country of new zealand.',
#   'Just brick an motar ads and stores',
#   'Just advertising new mobile phones',
#   'Special on Qantas points when filling up your fuel and purchasing further in store.',
#   'New product reviews,mainly motherboards and GPUs',
#   'A lot of negative feedback on the companies practices',
#   'about the products and the prices they have provided',
#   'Friend recently driven a Tesla vehicle',
#   'Interest Rate rises.',
#   'They have the best selling kitchen gadgets',
#   'Advertisements for Retirement Living',
#   'not bad',
#   'They have changed their packaging to recycles material',
#   'Mecca targeted ads on Facebook, product websites listing Mecca as stockists',
#   'Recalling all 2015-2017 SUV models because they catch fire.',
#   'Google music online & Google maps',
#   'Tv ads catalogue',
#   'email from mazda',
#   'Services  Purchased items  STreaming services',
#   'Social media posts and group forums',
#   'I heard that it is the largest athletic footwear store in Australia',
#   'Advertising on TV.',
#   'Cisco honoured human rights day',
#   'Recall on its electric vehicles',
#   'Just a ad promoting ebay',
#   'advertising on tv',
#   'About the electric vehicles in particular the Leaf',
#   'Specials they have. My Wife uses a lot of their products',
#   'Seen advertisement',
#   'The Lenovo computer is modern , durable and one of the best computers in the world',
#   'Points for purchasing fuel',
#   'advertisements',
#   'Seen an advert on television for them',
#   'The header who was',
#   'Just seen advertising to what they had on sale',
#   'Child labour, abuse and trafficking. Their abuse of people who can no longer access water that Nestle  bottle and sell. Their disgusting acts in the 90’s of bribing doctors to say their baby formula was as good as breast milk or better and giving it away until the mothers milk dried up. Who knows how many babies died from lack of nutrients and dirty water because of their greed. A company that big can afford to do things very differently yet they continue to do the wrong thing by people and the environment. They actually disgust me and I go out of my way NOT to buy anything made or sold by them or their other companies.',
#   'I HAVE SEEN REBEL SPORT',
#   'About the 300 series',
#   'chicken shorting',
#   'lego masters tv program',
#   'They send updates via email on privacy etc',
#   'Trying to sell off some of their retirement villages',
#   'Advertising for their services',
#   'THAT THEIR SHARE PRICES HAD DROPED',
#   'That they made over $2 billion dollars',
#   'Just advertising on TV',
#   'Advertisements regarding new discounts and deals.',
#   'Bay of Plenty Retirement Villages',
#   'TV ad campaign but paid no notice of what it was saying.',
#   'Use an acer laptop.',
#   'that they good quality products',
#   "Boss apologise for stating interest rates weren't likely to go up until some time in 2023 but they went up multiple times in 2022",
#   'Interest rate changes and perspectives about Philip Lowe',
#   'Constant interest rate rises',
#   'Ad on TV',
#   'An ad about Google working together with Chromebook.',
#   'Susan shadowbans or gives strikes to anyone she does not agree with politically. Google also strikes content and does not provide clear reasons why.',
#   'Exploiting',
#   'Retirement village',
#   'Interest rates',
#   'IAG New Zealand Limited provides insurance services. The Company offers home, auto, business, and personal insurance products. IAG New Zealand serves customers in New Zealand.',
#   'Bill board advertising at the shopping centre.',
#   'Good technology.',
#   'just the tv add',
#   'They have been increasing the interst rates while they said they would not.',
#   'Emails',
#   'Signage at sporting venues. TV advertising.',
#   'just there car ads on tv',
#   'that rates were going up',
#   'An accident',
#   'Just advertising',
#   'An advertisement',
#   'JUST ADVERTISING THEIR BRAND AND ITS PRODUCTS AND WHERE THEY ARE GOING',
#   'I saw the TV series Lego Masters.',
#   'Zacs',
#   'I have friends and family that are happy with their Hyundai vehicle',
#   'Communicated another rate rise',
#   'Saw advertising about its products',
#   'Advertising their products',
#   'Just in catalogues for specials.',
#   'Interest rate increase',
#   'changes to interest rates',
#   'Got a mailer in the post box advertizing an open home.',
#   'When i look for clothes especially shirt or t-shirt, Hush Puppies is one of my choices',
#   'Financial reports',
#   'Car dealer',
#   'I use eBay often, if I search anything in google eBay always offers items first that are competitive with other brands. Always seeing them on social media as well.',
#   'Friend used the service and was very happy',
#   'The fact that they have started using environmentally friendly packaging.',
#   'Teenagers having sex in parents rooms',
#   'saw an ad online for contents insurance I think. mainly remember it was AMI because of the brand and colours',
#   'Kafkskyskydymdbsmgstkektsyk',
#   'loreal is a great thing to have',
#   'general marketing and news reports, etc',
#   'Ads on TV for their phones',
#   'Their advertising and it basically tells me what I already know which is that Bupa is a great retirement village and a hospital care facility.',
#   'Watched as interest rates were dis',
#   'New platform edge routers and also Cisco Live exhibition.',
#   'I saw a article online outlining googles expansion plans for the future.',
#   'my mother is a Bupa facility and so I have seen a lot and heard a lot about them through her',
#   'Information concerning a maybe purchase.',
#   'Just a regular advertisment',
#   'Mortgage interest rates.',
#   'Car Ads in Newspaper',
#   'seen ads on tv for new models and sales on old models',
#   'Seen on bus the ad of price line. And articles',
#   'Offers and promotions for Christmas',
#   'making customers pay for car parking including medical people',
#   'Sale items for the Xmas season',
#   'one of my uncles overseas was saying how be bought it',
#   "Online merchandise for Christmas. Cheap grocery items when buying in bulk. Also, cheaper fuel than it's competitors.",
#   'Nestle are such a well known company who have been operating for years and years so it is hard to not see information or products.  And they produce chocolate so no advertising is necessary.',
#   'Items on sale',
#   'A tax bill',
#   'Normal advertising on free to air TV promoting their services to the public. Mostly speaking about the BP Fuel outlets where petrol and supplies can be purchased 7 days a week.',
#   'Signage on building sites where their products are being used.',
#   'Increase in the interest rate changes and why',
#   'TV adverts and price of their shares.',
#   'Media',
#   'News article quoting a local Rabobank manager that he did not have autonomy to make local decisions but things were controlled by Head Office.',
#   'Great quality',
#   'TV advertisements',
#   'Advertising for Christmas.',
#   'Adds on TV',
#   'that they are opening new stores in Melbourne',
#   'service and policy is good.',
#   'social media - tik tok',
#   'Great customer service and great support',
#   'An ad on TV where bluestone steel is used in the construction of a home',
#   'I see regularly promotions for Laser Clinics, particularly in large shopping centres.',
#   'Plenty of advertisement at the grocery store, caterlogs.',
#   'Pamphlet',
#   'Advertising some of theirnproducts',
#   'Billboards with car adds and adds between YouTube videos',
#   "That they're supplying products to the Russians regardless of the genocidal war Putin is waging on the poor people of Ukraine.",
#   'It`s advertising on National Television about Electricity',
#   'An advertisement on TV for Amazon Prime',
#   'passed by a local motor shop',
#   'Sponsorships through their flagship Westfield centres',
#   'The NZ owned businesses',
#   'Advertisements and the fact that they are removing bounty from their celebration boxes',
#   'They are producing a new state of the art laptop for consumers',
#   'The release of electric cars',
#   'advertising on social media',
#   'That tesla share price has dropped a lot since elon bought twitter he is dividing his time between to many businesses and tesla is suffering because of it',
#   'Television advertising about getting what you ordered or your money back',
#   'I watch a program on tv Lego masters'],
#  'CID': [23.0,
#   '48581',
#   '105134',
#   '107565',
#   131119.0,
#   '109092',
#   '10041',
#   '7641',
#   '83665',
#   '108607',
#   '61968',
#   131158.0,
#   '39653',
#   131161.0,
#   131165.0,
#   131167.0,
#   '108896',
#   131169.0,
#   '61456',
#   131171.0,
#   131172.0,
#   131174.0,
#   '96627',
#   131177.0,
#   '109328',
#   '10514',
#   131192.0,
#   131194.0,
#   131198.0,
#   131201.0,
#   '22222',
#   131207.0,
#   '103837',
#   131221.0,
#   131224.0,
#   131228.0,
#   131238.0,
#   '101355',
#   131243.0,
#   '103328',
#   '11415',
#   '11694',
#   '106084',
#   131272.0,
#   131276.0,
#   131278.0,
#   '101515',
#   131298.0,
#   '1270',
#   131299.0,
#   '103869',
#   '84783',
#   '102327',
#   131304.0,
#   '100081',
#   '101760',
#   131307.0,
#   '93579',
#   131312.0,
#   '102736',
#   '100983',
#   '103149',
#   '38131',
#   '84069',
#   131343.0,
#   '101524',
#   '18715',
#   '104608',
#   '102082',
#   '20454',
#   '16065',
#   '98705',
#   '107032',
#   '90215',
#   '60332',
#   '102072',
#   131403.0,
#   '104135',
#   345.0,
#   347.0,
#   '32581',
#   '45499',
#   '51311',
#   '13025',
#   '32662',
#   '109724',
#   '105119',
#   131458.0,
#   131461.0,
#   '104807',
#   '104806',
#   '21488',
#   413.0,
#   '108060',
#   '53627',
#   '28694',
#   436.0,
#   '79325',
#   '12850',
#   '84457',
#   '11701',
#   448.0,
#   '100311',
#   '101075',
#   '68354',
#   '58339',
#   '88131',
#   131537.0,
#   '98707',
#   '38855',
#   '105342',
#   '20769',
#   '70718',
#   131557.0,
#   '10756',
#   '38291',
#   '11997',
#   '108042',
#   '36828',
#   '93595',
#   '109388',
#   131585.0,
#   '13156',
#   131592.0,
#   '36244',
#   '37558',
#   '107749',
#   '40291',
#   '2795',
#   '103852',
#   '101894',
#   131641.0,
#   '96953',
#   131654.0,
#   '11483',
#   585.0,
#   595.0,
#   '104425',
#   '108262',
#   '59404',
#   '108894',
#   131701.0,
#   131705.0,
#   '37814',
#   131709.0,
#   '104268',
#   '83767',
#   '101083',
#   '103064',
#   '53131',
#   '4583',
#   '103586',
#   '14178',
#   '104934',
#   '104957',
#   '71912',
#   '20611',
#   '1251',
#   '106876',
# ...
#   'have used them in the past',
#   'My 86-year-old father flies Southwest to visit me.',
#   'have flown on Southwest in the past.',
#   'use to fly with them alot',
#   'Have flown in the past',
#   'Flown SW in the past',
#   'Fly with southwest before covid',
#   'Seen at airports'],
#  'Q_N_1109_002_98_other': ['Vacation trip',
#   'family death',
#   'travel on SWA',
#   'Flown them for over 15 years',
#   'long time customer',
#   'past experiences',
#   'They’ve been familiar for a long time in general',
#   'Past experiences with them',
#   'I remember when Southwest started flying',
#   'previous customer',
#   'have flown on its planes',
#   'Previous experience',
#   'Personal experience flying with Southwest'],
#  'Q_N_1109_003A_8_other': ['Free baggage'],
#  'Q_N_1109_003_8': [1.0],
#  'Q_N_1109_005A_8': [3.0],
#  'Q_N_1109_005_10': [1.0],
#  'Q_N_1109_005_7': [2.0],
#  'Q_N_11432_002A_4': [1.0],
#  'Q_N_11432_002_99': [1.0],
#  'Q_N_11655_001A_1': [66.0,
#   36.0,
#   10.0,
#   11.0,
#   12.0,
#   45.0,
#   14.0,
#   47.0,
#   54.0,
#   61.0,
#   31.0],
#  'Q_N_11655_001_1': [66.0, 41.0, 44.0, 46.0, 16.0, 54.0, 55.0],
#  'Q_N_11655_003A_1': [8.0],
#  'Q_N_11655_003A_1_98_other': ['Florida Health Care Plan',
#   'Devoted',
#   'Freedom',
#   'Health first',
#   'Tricare',
#   "Medicare - don't know who it's through"],
#  'Q_N_11655_003_1_98_other': ['Capital Health Plan',
#   'Obama care',
#   'Capital Health plan',
#   'BC BS Carefirst',
#   'Careplus',
#   'Freedom Health',
#   'American general',
#   'Melina',
#   'Devoted Healthcare',
#   'United American',
#   'oscar',
#   'Bright',
#   'Florida Healthcare',
#   'Athem',
#   'Blue Cross Blue Shield',
#   'Simply Healthcare',
#   'In between change right now',
#   'WellCare',
#   'Florida Health Care',
#   'optimum'],
#  'Q_N_11827_002A_1': [99.0],
#  'Q_N_11827_002A_2': [99.0],
#  'Q_N_1248_003A_2': [1.0],
#  'Q_N_1248_003A_5': [1.0],
#  'Q_N_1248_003_5': [1.0],
#  'Q_N_1300_007A_5': [1.0],
#  'Q_N_1300_007_9': [1.0],
#  'Q_N_153_003_4': [1.0],
#  'Q_N_1649_005_3': [1.0],
#  'Q_N_2373_004_999': [1.0],
#  'Q_N_3603_002A_98': [1.0],
#  'Q_N_3603_002A_98_other': ['Works to prevent violence and abuse of guests and employees at all levels',
#   'behaves ethically in general',
#   'Disgorge embezzled funds.',
#   'Allow more hookers',
#   'Pays their employees fairly',
#   'Just do business and stay out of politics and social issues'],
#  'Q_N_3603_002_1': [0.0],
#  'Q_N_3603_002_3': [0.0],
#  'Q_N_3603_002_5': [0.0],
#  'Q_N_3603_002_6': [0.0],
#  'Q_N_3603_002_7': [0.0],
#  'Q_N_3603_002_98': [0.0],
#  'Q_N_3603_002_98_other': ['Do what they do best in entertainment. All companies do not need to give in to the left liberal Social causes.',
#   'HAS PROACTIVE VISIBLE SECURITY IN PEDESTRIAN AND PARKING AREAS ATTACHED TO PROPERTIES',
#   'none',
#   'Other'],
#  'Q_N_3669_001_7': [1.0],
#  'Q_N_4886_006A_2': [1.0],
#  'Q_N_5021_002A_1_98_other': ['My advisor uses them',
#   'i am a former client',
#   'Or accountant manages our investments through lpl',
#   'recommended by my financial advisor',
#   'Credit switch to you assholes',
#   'I have heard of this company before from other people'],
#  'Q_N_5021_002_1_98_other': ['Past client',
#   'I had investments with LPL',
#   'Financial Advisor uses LPL',
#   'Family works for LPL',
#   'I invested with them 15 yrs ago',
#   'I previously worked in financial services',
#   'My advisor works for LPL',
#   'Talked to LPL Financial advisor for investments thru LPL',
#   'I have an IRA through them',
#   'My financial advisor buys stocks from LPL',
#   'None',
#   'Former customer',
#   'previously worked in financial services',
#   'My advisor is with LPL',
#   'Invested with them'],
#  'Q_N_5021_004_98_other': ['I bi-weekly contribute to my own retirement account.',
#   'speak to my financial planner'],
#  'Q_N_5157_002A_98_other': ['space,cyber,software',
#   'Emerging Technologies',
#   'Government Contractor',
#   'Cyber',
#   'Military Systems',
#   'military/industrial complex',
#   'education (college)',
#   'Comat vehicle manufacturers',
#   'Environmental Science'],
#  'Q_N_5157_002_98_other': ['Defense',
#   'Government Digital Transformation',
#   'Virtual Reality (VR)',
#   "providing gov't agencies with contract employees",
#   'Government research',
#   'NASA contracts',
#   'Oceanographic Applications',
#   'Military C4I',
#   'Space engineering',
#   'Defense Contracting'],
#  'Q_N_5240_001_1': [5.0],
#  'Q_N_5240_002_1': [98.0],
#  'Q_N_5240_004_1': [2.0],
#  'Q_N_5603_004Ax1_98_other': ['Tractor supply',
#   'Alpo',
#   'Cat food',
#   'Pet supplies plus',
#   'Na',
#   'Don’t purchase wet food',
#   'Do not use',
#   'chewy',
#   'chewy.com',
#   'Flea market',
#   'HEB grocery store',
#   'Convenience',
#   'military commissary',
#   'Marshall’s'],
#  'Q_N_5603_004Ax2_98_other': ['Craft show',
#   'target',
#   'Na',
#   'manards',
#   'N/A',
#   'Marshall’s',
#   'Dollar tree',
#   'Chewy',
#   'Convenience',
#   'Amazon',
#   'military commissary',
#   'chewy'],
#  'Q_N_5603_004x1_98_other': ['Feeders Supply',
#   'do not purchase',
#   'Big lots',
#   'none',
#   'TSC for horse feed',
#   'Commissary',
#   'None',
#   'CHEWY',
#   'Grocery store',
#   'Chewy. Com',
#   "I don't buy wet food",
#   'Bakery',
#   'Safeway',
#   'I use Chewy.com',
#   'key food',
#   'Purina For Professionals website',
#   'chewy'],
#  'Q_N_5603_004x2_98_other': ['Feeders Supply',
#   "Don't purchae",
#   'do not purchase',
#   'Military',
#   'Do not use wet food.',
#   'Chewy. Com',
#   'nothing',
#   'Chew',
#   'Chewy.com',
#   'Prettylitter.com',
#   'chewy'],
#  'Q_N_5603_005A_98_other': ['No number three',
#   'made in usa',
#   'Your survey is crap! I tried to select none of the above. The other two options I select are BS',
#   'price'],
#  'Q_N_5603_005_98_other': ['My Dog Likes Pedigree',
#   'some of all of the above'],
#  'Q_N_698_002A_3': [3.0],
#  'Q_N_698_002_2': [2.0],
#  'Q_N_698_002_3': [3.0],
#  'Q_N_707_001A_21': [1.0],
#  'Q_N_707_001_13': [1.0],
#  'Q_N_7966_001A_1': [1.0, 6.0, 9.0, 18.0, 19.0, 21.0],
#  'Q_N_7966_001_1': [6.0],
#  'Q_N_7966_003A_1': [16.0, 10.0, 15.0],
#  'Q_N_7966_003_1': [8.0, 4.0],
#  'Q_OE_10771_003A_1': ["I'd like to see extensive improvements in security.  It seems like any company can get hacked anymore.  No one can feel completely safe online. I would like them to improve and guarantee their security measures.",
#   'Being able to help their clients and feeling safe on where you are leaving your money at.',
#   'More push to move online',
#   'I would like to see more financial education for young people. Money is not taught enough.',
#   "In really don't care don't use this financial institution",
#   'The Beat the same time I have to let her',
#   'Better rates to customers',
#   'Higher interest rate would be nice',
#   'More functional online banking software and better fraud protection',
#   'I would like to see the bank, have more perks to draw in new business.',
#   'Higher interest so we can save more money in the banks.  Nobody saves anymore',
#   'Don’t have them as a bank or service',
#   'Like to see them become more personal. Also to reduce annoying fees.',
#   'Less predatory lending and banking fees',
#   'A cheaper mortgage',
#   'Being fiduciary to their clients',
#   'A simple and efficient way to invest in multiple kinds of investments',
#   'fair and open communication',
#   'Lower rates!',
#   'Online banking',
#   'To be able to give loans to people for housing with good credit',
#   "Better integration with financial software (like Quicbooks for smaller companies. The systems they have just don't work the way a bookkeeper would like.",
#   'Better personal financing tools … ways to save and track spending habits',
#   'Less charges for over draf fees.'],
#  'Q_OE_10771_003_1': ['Simpler explanations and terms for home and business loans. More accessible.',
#   'More technological advances to make it easier for consumer',
#   'Online banking options.',
#   'More online products',
#   'More cash back incentives',
#   'better interest rates',
#   'Honesty and no fees for using any atms anywhere at anytime',
#   'Focuson improving products and services and stop investing into the unrelated and harmful gimmicks like DEI and ESG.',
#   "I would like to see banks give second chances to some that have fallen in to check systems. Not all are by  negligence and just not carrying some are voicemail of circumstances that they can't help and for that I think there should be a program where individuals that fall in this category can apply for forgiveness and a 2nd chance to function in the real world instead of being shunned as per say",
#   'Ways to help people in debt.',
#   'From my bank ,Wish I could do more over the phone, instead of going in just to make a appointment with the Manger to open a new account,',
#   "I hope that they remain tech-saavy. I hope that they offer incentives to customers, so that they don't turn to credit unions.",
#   'Making loans more available to lower income customers',
#   'perhaps more online banking , although that is growing quickly already    . Need to stay away from those quirkly trends like Crypto , and Bitcoin',
#   'Be more accessible',
#   'Help people save money and also help them save money',
#   'Debt forgivness',
#   'Some  town hall  type events.  Limit # of folks in attendance so participants have more of an opportunity to interact with the speakers',
#   'More locations',
#   "To be honest, this isn't something I would normally think of.",
#   'Something for everyone, I believe if you are a bank you should have a service available for everyone regardless of history or income. Education and programs with incentives.',
#   'Job Stability for starters.',
#   'More access to low interest loans.',
#   'different investment options',
#   'Open and honesty about loans and loan pay-offs  Diversity in the workplace   Creating more jobs for the unemployed',
#   'More transparency and more accessibility for people in every part of the economic spectrum.',
#   'Online banking and mobile banking.',
#   'I hope to work for citizens bank',
#   'more person to person contact',
#   'I do NOT hope to see digital banking',
#   'Better security for online transactions',
#   'UPDATED COMPUTER TECHNOLOGY',
#   'Mpre privacy from government',
#   'NONE',
#   'A more fair creadit check. If someone is poor shouldn’t be trapped in poverty',
#   'Better interest rates and more help making ends meet.',
#   'Grow  and prosper',
#   'Honestly, I am a paper person, I want it back to normal,',
#   'More drive thru locations near my home',
#   'Clearer communications.',
#   'Lower interest rates'],
#  'Q_OE_2828_011A_1': ['fuels',
#   'It is appealing',
#   'Very good',
#   'Petronas Oil  Petronas carbon dioxide',
#   'Great',
#   'They have a wide range of unique and high quality products',
#   'very good',
#   'IT IS NEW BRAND',
#   'All I bought were these shoes for my son and that’s honestly all i bought I don’t really have a negative feeling to say about them',
#   'it is good',
#   'fdfgfdgfdg dfsd aswd sf dgfgh fh fd gsdf fd',
#   'Excellent good',
#   'Good',
#   'Very like',
#   'Good quality',
#   'Energy',
#   'dsfsdsdfsd',
#   'It is very great',
#   'Oil and energize clean',
#   '21er',
#   'high reputation',
#   'Very nice',
#   'i lovely',
#   'Processed gas',
#   'I BOUGHT OIL FROM PETRONAS',
#   'No comments',
#   'very good and very nice',
#   'just samples'],
#  'Q_OE_2828_011_1': ['I’m pretty sure I got gas from petronas',
#   'Car parts',
#   'It’s wouldn’t change my mind',
#   'great',
#   'yes',
#   'OIL',
#   'Fuel purchase',
#   'Very good',
#   'Mercedes AmG jacket',
#   'It is very well',
#   "I'm sorry it been away back and can't remember.",
#   "It's very good",
#   'Oil',
#   'Oh just a whole lot',
#   'I’m sure I’ve used their fuel somewhere along the way',
#   'No',
#   '10w-40 engine oil',
#   'dfg fgh dg f',
#   'fgjghjghmkg',
#   'I used the air humidifier to cleanse the room air',
#   'Gas',
#   'GAS',
#   'Synthetic engine oil and F1 products.',
#   'Information technology and services to the other hand the other hand the other hand the other hand',
#   'an oil for my car',
#   'NO',
#   'Good',
#   'Clean slate of the Vision',
#   'i think its good',
#   'n/a',
#   'Did some machine work',
#   'u',
#   'I purchased $100 gift card.',
#   'mercedes and more patnered companied wardrobe',
#   'I use the synthetic PETRONAS oil',
#   'I had used every possible item that PETRONAS has produced.',
#   'Products & services they provide that’s environmentally ecologically sustainable friendly supply’s I purchased',
#   'I purchase oil and fuel products from them',
#   "Yeah I mean products and services in the United what they're doing through the fucking refiner reset me I'm using a product center and it's all top greendy products I mean you can't get them anywhere looking at them from them",
#   'it is best service given us',
#   'this is very good'],
#  'Q_OE_5240_005A_1': ["Two women bilked some of USAA's customers",
#   "Just about their support of veterans active or not. It's not really new because I have heard about it before.",
#   'Tv commerical',
#   'It is sad what I seen an heard',
#   'warriors lives are honorable and fulfilling',
#   'The prices of USAA have GONE UP.  They usually had the lowest prices and the best service.  But I cancelled after almost 36 years with them',
#   'Friend was discussing the insurance prices being the same as Amucas.',
#   'I have seen commercials about how this company serves veterans and their families',
#   'My coworker described a good experience with USAa with insurance for a new roof.',
#   'supporting our veterans',
#   'someone had a very good experience in an auto claim. The customer was very pleased.   Very pleasant to work with.',
#   'how they cater to veterans that have served in the military',
#   "I believe the former pro football player was used in a couple of the company's ads.",
#   'I heard that USAA solved a problem quickly for someone in a caring, professional way.',
#   'Low car insurance rates'],
#  'Q_OE_5240_005_1': ['Usaa is a great company that takes care of their military members',
#   'USAA customers spoke highly of their insurance when they were renting a car',
#   'I saw an ad on HGTV seem to point out the positive attitude of the people involved as customers and the company and its representatives.',
#   'USAA provides excellent products to multiple generations of a family',
#   'Is a good place to be and they love doing that',
#   'I liked the way it represented USAA',
#   'A tv ad explaining how UDAs helps service people',
#   "Insurance department doesn't pay very well",
#   'USAA provides insurance to those who protect and serve our country',
#   'Available to military members and their dependents',
#   'It good card to use for events going down in the world today since the cost is lower than any other card.',
#   'my Husband is a Veteran he and our friends trust and believe in USAA',
#   'Television ads explaining how family members of veterans can get coverage through USAA.',
#   'helps insure veterans & their families',
#   'people using them to purchase homes',
#   'How usaa helps the military family',
#   "I'm not sure exactly what it was but something about it's overall costumers losing millions of dollars collectively.",
#   'good business practices',
#   'It was a good ad',
#   'They are quick to respond to their customers and get things done.',
#   'I see their ads all over the place',
#   'Helped my son with an insurance claim.',
#   'very impactful',
#   'NFL player Gronkowski doing anything he can to get a USAA membership and being denied at every turn.',
#   'An ad that promoted how it can help veterants.',
#   'My ex girlfriend was a active member of the military and we had USAA because of her. I still see there ads on my Facebook pop up from Time to time and the TV ads',
#   'happy thing thanks is games going today',
#   'What the company about and what it represents',
#   'They support service members',
#   'Commercial on tv',
#   'Helped service people with savings',
#   'How they help all military',
#   'Advertisement for Certificate of Deposit rate increases',
#   'very excellent',
#   'value',
#   'Someone told my husband we could save money on our car insurance.',
#   'i likrpe the tv ads, always makes me think it would be good to qualify for this',
#   'I saw a friend get a quick response from USAA when Hurricane Ian tore of his roof. It was all settled and fixed within three weeks.',
#   'Services for military personnel and their families']}

# %%
dict_missing_uni_val
# Out:
# {'AGE_ORI': [112.0, 109.0, 103.0],
#  'AP_AW2_1': ['Mercury is building a windfarm in Southland New Zealand',
#   'iron ore sales to China',
#   'PRIVELINE IS A HUGE TRADING COMPANY',
#   'cars',
#   'Constant raising of the cash rate non-stop since the start of the year',
#   'Sexual assults on women in the workplace',
#   'Ads online',
#   'I seen they sponsored a sporting event. I can’t remember what though',
#   'many things. 3rd quarter earnings.....i watch blogs and you tube videos on Tesla',
#   'Disputes about paid parking at the Tea Tree Plaza Shopping Centre.',
#   'the company customers details being hacked',
#   'i like it',
#   'Repetitive ads about The Landing.',
#   'I am to lenovo',
#   'quqlity',
#   'new products good promiotions on products',
#   'Work colleague using service for family member',
#   'I feel that way',
#   'Very',
#   'They have had a massive cyber breach of their current past and present members personal details.  They have not taken any steps to remedy the situation and are not communicating with their customers very well.  Their CEO said they did not have insurance against Cyber crimes.',
#   'Is a reputable brand.',
#   'I am or seen relating to private',
#   "Their Add on TV about Ebay's special buys on Tuesday",
#   "IT' SO GOOD",
#   'That it is doing great job by building residentisl and retirement living communities as well as retail town centres etc. It is praised for its treatment of its employees with work-life balance',
#   'nice',
#   'There catalogue',
#   'that they have been hacked',
#   "it's is very goods.",
#   'A significant data breach',
#   'I have read they are value for money for budget conscious consumers',
#   'Makkah',
#   'I am to ebay',
#   'Only LEGO masters with Hamish Blake',
#   'I am thinking',
#   'Stockland has sold its retirement villages.',
#   'I read it mAny information new.',
#   'Adds for products',
#   'fdbdfb hgnghn',
#   'Trustpilot reviews are all negative from customers and ex customers.',
#   'Read positve things about products for sale on amazon on social media',
#   'It is good',
#   'About their CEO',
#   'Something to do with the future of cars',
#   'TV advertising about hospital and extras cover',
#   'an ad on tv',
#   'How much profit they made in the last year and how much of the environment they’ve destroyed',
#   'They have made an offer for OZ Minerals.',
#   'an email',
#   'Ads on TV',
#   'Data breech',
#   'I have seen and heard advertising',
#   'More develop',
#   "musk's takeover of twitter and disgusting remark about pelosi incident'",
#   'I think I have read about it.',
#   'I have seen the new Google pixel phone just come out',
#   'I read it on social media',
#   'Visited my aunt who lives in the village here in nelson',
#   'I am a small shareholder so read financial reports etc',
#   'they advertise a lot',
#   'i read',
#   'A friend of mine has insurance with AMI and they are refusing claims and stalling the situation',
#   'TV advertising for various new models of vehicles',
#   'Australian coins is an interest of mine',
#   'Great idea and experience',
#   'hacking of its information',
#   'nnn',
#   'i like brand',
#   'freshness',
#   'Write ups of new models.',
#   'More offer',
#   'recall on motors',
#   'RioTinto blasted an Aboriginal sacred   Site, they knew what they were doing & went ahead with it all the same.  Unconscionable behaviour',
#   'i saw some ads',
#   'Some advertising online.',
#   "I hear a lot about the brand's advertisements",
#   'I am very good',
#   'best',
#   "The brand name seems to pop-up everywhere everytime, but I did not pay attention to the contents as I wasn't interested",
#   'Scams in private details of members',
#   'Tesla Ceo Elon Musk going to the moon',
#   'Very nice and beautiful full',
#   'they plan to import cars from China',
#   'GOOD QUALITY',
#   'Jeff Bezos is going to give away his fortune',
#   'Catalogue prices',
#   'new news.',
#   'Information technology and services to be in',
#   'Partner worked on a lendlease job site',
#   'The new EV Ioniq, very nice car',
#   'the increase of offical rates by 0.25%',
#   "I'm a Bupa user, so I receive emails about related offers often",
#   'I heard good comments comparing to other services from bupa employee',
#   'Just seen video ads before watching YouTube videos.',
#   'READ ALL BUPA NEWSLETTERS AS MY MOTHER RESIDES IN ONE OF THEIR RETIREMENT VILLAGES',
#   'launches new products',
#   'I do not know',
#   'we went into big w and we looked at the lenovo products and knowing we own lenovo we nearly purchased another item',
#   'Flyer in a local newspaper',
#   "We have Amazon Prime not very happy. Seen lot's ads for Amazon on tv",
#   'specials',
#   'It was an ad on TV about a woman creating headwear for cancer patients supported by Oceania',
#   'reard',
#   'Products being used on The Block',
#   'I have looked on eBay just to see if anything catches by eye to buy',
#   'I saw it on youtube',
#   'Received an email newsletter, plus have seen adds on tv.',
#   'general advertising  Other comments relate to this industry as a whole and are generally negative.',
#   'A lot of negatives',
#   'price rises',
#   'you tube',
#   'mmm',
#   'New electric car will come to the mkt .  KONA',
#   'something regarding malfunctions',
#   'Refreshment.',
#   'Information technology it',
#   'About the breach of privacy, hacking of members’ details. Also lack of confidence in the CEO who is a young woman. Lack of online security',
#   'Christmas Lego show on TV',
#   'A brand with top quality.',
#   'data security issue. System was hacked',
#   'advertising for events at our local shopping centre',
#   'Advertisment',
#   'I read it on Facebook.',
#   'i like much',
#   'A new Priceline coming to our local shopping centre.  Alot of signage.',
#   'Scandal about employees and former emloyees',
#   'Government blaming them for their own problems',
#   'gndg db db',
#   'Insurance claims for property damage up 34% - but still not enough action on climate change',
#   "Summerset Life  Enjoy the peace of mind of living in a warm and friendly retirement community where you'll feel completely at home.    33 villages across New Zealand  Designed for over 70s  Choice of villas, townhouses, apartments and serviced apartments  Range of care options including rest home & hospital level  Additional support on hand  Easy access to facilities & community spaces",
#   'Advertising new vehicles',
#   'Investment platforms',
#   'They have high quality in services',
#   'Data breach and the client sensitive info leaked to public because they refused to pay ransom.',
#   'Have seen a Kona ad on TV. Saw there were recalls on some Venue cars I think',
#   'I read and listen to Scentre group very well',
#   'Rabobank is seen as a major contender for second tier lending in the property investor circles',
#   'policy suitable for senior citizeb',
#   'I saw an ad on t.v representing one of their new cars a few months ogo',
#   'Ebay Tuesday ads on tv',
#   'It has been the victim of cybercrime',
#   'People talking positively about their rewards system',
#   'very good quality',
#   'Visited a retirement village',
#   'Brochure sent with the local newspaper',
#   'like very',
#   'sdgsdfgf',
#   'high application.',
#   'Radio advertising',
#   'Heard a lot of news commentary on data leak',
#   'It has good security.',
#   'fddf  fdx fd',
#   'That car crash',
#   'Trying to get people to join them with a TV add.',
#   'Tv commercials and tv show.',
#   'Information on the new ford ranger',
#   'ok',
#   'I read and listen to cisco very well',
#   'Very nice jaan celebration of my life is sawal',
#   'Hacking breach and millions of peoples person data and medical details have been stolen from medibsnk private.',
#   "They're not going to insure central nsw any more",
#   "Im always seeing toyota ad's on the tv and youtube ad's im also receiving reminders for services for my car",
#   'sd',
#   'quality good.',
#   'Raised interest rates on Melb. cup day.',
#   'they will cause 30% of homeowners to lose their homes.',
#   'The TV show Lego masters',
#   'nothing',
#   'That RBA increased the interest rate',
#   'flu season medication',
#   'the reoaganization of some of there stores',
#   'It is a brand that is loved by many people.',
#   'Commercials',
#   'service quality',
#   'Saw the ad',
#   'a new product range from avatar to harry potter . good to come together. excellent idea come from lego. cool thing to come together',
#   'Very good',
#   'Very much',
#   'Their trucks on the roads',
#   'fbfdb fgbrf',
#   'HP Inc very good',
#   'Seen a TV add about ebay',
#   'THEY BUILD QUALITY MOTOR VEHICLES THAT RUN FOREVER - I HAD ONE ABOUT 10 YEARS AGO.',
#   'I read it on Social media',
#   'qual;ity',
#   'share price. mining reports',
#   "I don't  know.",
#   'Tv advert',
#   'Their new retirement home',
#   'I feel very useful',
#   'Information technology it manager',
#   'I constantly get emails from ebay',
#   'Tv & newspaper  advertising',
#   'Very nice and beautiful pics',
#   'srv dv',
#   'Friends telling their experiences with them',
#   'It was good I guess',
#   'Only the ads on TV, like Ebay Tuesday',
#   'It is very good and safe',
#   'I HAVE SEEN AND SEEN MANY ADS FROM THIS BRAND',
#   'An advertisement for their retirement home',
#   'Very friendly',
#   'advertisments on televsion',
#   'like',
#   'More offer and quality',
#   'TV ads    Visited friends living in BUPA village',
#   'That they support people buying EV cars',
#   'Discussion about the succession after Rupert dies.',
#   "My sister recently purchased items from Adair's and was very impressed with the quality of the products.",
#   'ongoing failure to provide accurate, ethically sourced non-partisan information for the reading public. Internal fighting. Anti-democratic practices. Interfering in Australian and USA elections. relic of the past.',
#   'friend said to go',
#   'ANZ',
#   'read hears',
#   'put a hold on increasing premiums',
#   'Sacking thousands of employees',
#   'I have seen ads on TV for the latest Nissan cars.',
#   'it is comfortbale',
#   'Hacking, lack of data security',
#   'Data breach',
#   'Very poor customer wervice',
#   'a advertising brochure in the press',
#   'None',
#   'AsusTek was offering me online storage for my anoying Asus laptop.',
#   'An ad',
#   'useful',
#   'likely',
#   'Very good morning sir g',
#   'A data breach of personal information for clients past and present.',
#   'The reserve bank is increasinginterest rates on loans which in turn boosts the interest rates on savings and investments',
#   'Lenovo sponsors racing cars',
#   'Special prices',
#   'Cyber attack',
#   'TV commercial',
#   'hacking private information',
#   'Cars',
#   'very necessary',
#   'Vyyyy to a message for you and your',
#   'retail specials on computers.',
#   'very vey good',
#   'The new laptop cum tablet',
#   'Specials at Priceline',
#   'They recently announced a significant reduction in their annual profit',
#   'can not recall just remember seeing them on ntv what it was about have no idea',
#   'I’m going back home now I have a couple things I have',
#   "Not sure now. There's often little snippets that I come across. I don't recall though",
#   'email, tv add',
#   'They are good quality  cars',
#   'Email notices from email.',
#   'i like them',
#   'CEO (BHP/Billiton) going too woke.  In Australia they offer me no concerns but in Africa they lower their standards.',
#   'Qualityful products.',
#   'Adds',
#   'good service',
#   'news',
#   'Share prices and job ads',
#   'Email advising about security on line',
#   'Staff working conditions',
#   'Information technology it headache',
#   'sdfgsdfgsdfg wertwetr sdfgsdfg cvbcxvbcxbv ghfgdhdfhrf hgfghre tyerty fdghdfgh vcbncvbncvbn',
#   'That they have a lot of specials',
#   'thntrn fbf',
#   'Positive',
#   "I don't know",
#   'I heard and saw on TV recently that they raised rates again.',
#   'I feel the confident.',
#   'A progressive organisation',
#   'I feel very usfeul',
#   'I read that Mars is an unethical company that doesn’t care for the environment and has unhealthy products.',
#   'Heard very good company',
#   "It's good quality.",
#   'Promoting EVs',
#   'I follow Rhodes Waterside on social media. The most recent update being a Remembrance Day post.',
#   'adverts',
#   'high quality',
#   'Very like.',
#   'suitable and quality',
#   'In a google search relating to alternative products',
#   'the debacle of their shopping centre at Geebung being pulled down after the February floods and tenants not being compensated',
#   'Very easy',
#   'Latest weekly deal',
#   'It is famous',
#   'veyr good.',
#   'positive',
#   'i have read about it',
#   'read heard',
#   'Supporting and providing more opportunities',
#   "it's great",
#   'Information technology',
#   'DSGSDFGDF',
#   "Can't recall",
#   'Low quality cars that always have problems,',
#   "it's so great",
#   'db d dbdb',
#   'lots of emails with product offerings',
#   'cxvfdgfh',
#   'I use google every day and have a gmail account',
#   'Good information',
#   'Rasing interest rates',
#   'Very good morning sir ji time to explore new technology and I am not able to attend the all',
#   'Video sand',
#   'That has several retirement homes to occupying by patients',
#   'Security breaches to their systems , ransom being asked for data breaches',
#   'They are a sponsor of the Richmond Football Club so their branding is very clear.',
#   'I see quality',
#   'ads from YouTube',
#   'interesting',
#   'Aged care facilities',
#   'Open house for all potential customers',
#   'Powerbill',
#   'I believe I saw an ad in the print media',
#   'Changes to interest rates and their perspective on inflation and the economy',
#   'Amazon treats its employees terribly and has caused several deaths',
#   "Elon Musk's takeover of Twitter",
#   'Their general news articles',
#   'Poor reporting standards',
#   'Have been shopping there',
#   'They are amazing',
#   'Majority shareholder, Rupert Murdoch, involvement with trump',
#   'I have seen that their data was breached and how they have handled it',
#   'Tv ads showing a couple from youth to old age and them enjoying piano playing and visits from their children and grandchildren. Looks a nice environment.',
#   'Yes Amazon is selling air fryers for $29 in is this a scam',
#   'Interest rates rising',
#   'good quality',
#   'Advertising on the computers on the internet',
#   'increase of interest rates',
#   'Seen their computers at work',
#   'Received emails with offers, as well upcoming payment reminders',
#   'premium increases',
#   'I have read and heard Lego group very well',
#   "People I know use it often and post very positive results with their children's creativity with the blocks",
#   'no',
#   'No Medicare as we are temporary residents. Gotta look for a health care insurance and we came across BUPA online.',
#   'New product launches',
#   'I get updated email from them,sometimes daily.they are great',
#   'An ad about the Pepsiverse.',
#   'advert',
#   'Not sure if it was an add on TV or online. Whichever it was it was very positive. And I enjoyed the add.',
#   'On the Block',
#   'I love this survey',
#   'have friends that do sub-contract work for them, for which at times have been involved, they appear to be great communicators with them personally,yet some employees tell a different story ,',
#   'emails adverts for land developments',
#   'Job advertising',
#   'VERY LIKE.',
#   'ppoTSL69&~',
#   'Their Retirement Village',
#   'nfhj',
#   'velang',
#   'they are having fracking',
#   'Tech savvy not just cars but electric and hybrids',
#   'gndg hrdn dtn',
#   'That you can earn lots of Flybuys points if you join.',
#   'That is car very good',
#   'Ads relating to taking our policies',
#   'Foldable phones',
#   'i read about they progress saver account that generate good year return investment',
#   'very like',
#   'Advertising on television',
#   'How the company is going after the pandemic',
#   'read emails sent by a company that sells Dell laptops desktops ect and perused some of the laptops particullay the Alienware range',
#   'Information technology it manager headache',
#   'Good product I will support the product a lot.',
#   'The company operates a commentary program which is highly biased, politically, socially  and economically and which creates dangerous social division in the community.',
#   'just the funny ads',
#   'christmas setting',
#   'ctaIUZ63^!',
#   'is a large online sales site',
#   'care and management of Bupa establishments regarding patients and wellbeing',
#   'very good much',
#   'their largest quantum project yet',
#   'Very great and quality',
#   'Seen an ad on tv',
#   'Good quality.',
#   'is very good',
#   "It's very like",
#   'Just TV advertising',
#   'JUST AN AD ON TV',
#   'emails to me',
#   'Toyota club membership',
#   'I have learnt about some of their new and innovative products.',
#   'cíco',
#   'PRESTIGE COMPANY',
#   'More offers',
#   'Generating new energy resources',
#   "Can't remember but was good",
#   "My friend had a Hyundai 7 years old and the motor needs replacing. It's evidently a common problem with Elantras but nothing is being said or done about it.",
#   'TV, flyers',
#   'Information technology it headache Manezer',
#   'Tv',
#   'Private health insurance',
#   'Read up on their ambulance insurance',
#   'The pre-eminent portfolio',
#   'I find it very good.',
#   'Dear friend died in their hospice section. Exemplary but overworked staff, indifferent food for people recovering (in the hospital section)',
#   'Advertisement for products',
#   'Very good morning sir g sir please find the',
#   'they are on the stock market and I have been watching them.',
#   'cz',
#   'Quality good.',
#   'advert on TV',
#   'This is very beautiful place',
#   'QW',
#   'It is very good',
#   'dádf',
#   'I have r ad the regular newsletter at the Jean Daniel Ryman village, where my mother lives',
#   "Very expensive EV's",
#   'Data security breach, as they didnt want to pay the insurances',
#   'I read and listen to unilever very well',
#   'Advertisement for Rt display and site visit',
#   'aodBMS33^%',
#   'Their advertisements for various Insurances on television.',
#   'General product advertising,  social media posts',
#   'Very nice and beautiful full survey',
#   'Cyber hacking',
#   'How it makes good offers for glasses and its dentistry',
#   'dgsdgdgsdf',
#   'i think that i love it',
#   'Quality',
#   'Nice',
#   'MODERN',
#   'It’s a very good platform for buying',
#   'Advertising relating to various mofrld sof mcard.',
#   'Very nice and beautiful',
#   'My 18yr old daughter purchased a lego set with a friend.',
#   'relating to the board',
#   'Elevated interest rates',
#   'B a try ttttt in t',
#   'Store Adverstisements',
#   'i likes survey.',
#   'Information herein family reunion',
#   'Golden kiwifruit on display at supermarket',
#   'Emails of items i might be interested in',
#   'Ive seen on Facebook how in America they had employed sneaker testers to check if shoes are real or legit.',
#   'I read pon the book',
#   'fgsd fdgdfhdhds gd bnbvn hsd gfgsfdsh s',
#   'I very many information new.',
#   "I'm very great.",
#   'lots of advertising on tv',
#   'Read brochures   Family member wad in there for a short time   The staff are fabulous   The place wad new and beautiful   She wad happy there for the shory time',
#   'ITS STILL DOING WELL WITH IRON ORE EVEN THOUGH CHINA IS STRUGGLING WITH COVID PROBLEMS AND A DOWN TURN IN ITS ECONOMY',
#   'very quality.',
#   'The NIB is great place for health insurance',
#   'they bought two more retirement villages, their profit was down',
#   'They are increasing their premiums like  many other funds',
#   'I have received weekly emails from them and also browse the store often',
#   'I heard image promotion',
#   'quality very much',
#   'Great electronic',
#   'moder',
#   'Tender application for works in Christchurch',
#   'trust.',
#   'Information about the day',
#   "i don't know",
#   'I have heard good things from people I know talking about how helpful ebay was',
#   'Amazon helping with child cancer charity',
#   'Companies have not paid tax',
#   'Very good morning I am also',
#   'TV ad campaign re ‘too busy lives’',
#   'The new phone thats out its like a flip out phone like 2 in 1',
#   'Serving well here in our local community',
#   'I got a quote online for car insurance',
#   'pixel ad',
#   'Very good morning sir ji time to explore',
#   'google has been upgrading their systems due to all the hacking that is going on',
#   'Just ads on tv about getting free delivery when you buy things',
#   'About the governor and constant interest rate hikes',
#   'Telling lies',
#   "Buy swap and sell site for Adair's products",
#   'Frequent updates on the RBA interest rate increases and the economy',
#   'Increasing interest rates every month that results in deep inflation.',
#   'dsfsdfsdfs',
#   "I can't remember details but they're trying to sell that they're doing good things for Australian land. Bollocks",
#   'it is the best for gamer',
#   'ford escape seems to be a good choice for families (as seen on the block)',
#   'I saw an article about said group on facebook',
#   'My partner is with them and says they are outstanding',
#   'Rewards its customer.',
#   'I seam it quality',
#   'Radio ads',
#   'Very good morning',
#   'increasing interest rates to slow inflation',
#   'Regular emails from Costco',
#   'With relation to the data breach',
#   'I am to mars',
#   'I have seen advertisements',
#   'Mazda, increasing the Hybrid vehicles',
#   'very good.',
#   'Staff reviews with overwhelming comments about a company focus on profits therefore offering low wages',
#   "They're always in the news announcing interest fluctuations.",
#   'Word of mouth experiences from family friends and neighbours',
#   'Good TV ads but do they really reflect the company and people who reside there?',
#   'Seen their product on the block',
#   'I feel very helpful.',
#   'rebel sport is a famous sports fashion brand',
#   'Our company does work for them. We updated our work policy',
#   'very great',
#   "Medibank's customer's data hacking",
#   'rio tinto is a corporation specializing in construction',
#   "it's very great",
#   'hp laptops',
#   'YES',
#   'Cyber leak',
#   'Barred from 5Gmobile phone rollout in Australia as well as other countries because of privacy concerns.',
#   "The appalling hacking of Medibank's computer system and the ransom demands.",
#   'Ad before the weather on news',
#   'Innovative',
#   'special',
#   'advertising cottages',
#   'Latest share price movements',
#   'sdgsdgsg',
#   'Move with Mercury and get cleaning vouchers',
#   'Been to appointments',
#   'No for petrol station',
#   'dvdb',
#   'Very good morning sir g sir please find the attached very good morning sir g sir please find the attached file is scanned image in PDF format hai to usne chek the',
#   'Adverts on the internet',
#   'Viewed TV commercial which advertised the Ford vehicles',
#   'Advertising in newspapers',
#   'Ford has stopped production.',
#   'Saw an ad for Samsung on YouTube',
#   'Summerset is opening its second community which is large and looks great  I have several friends that have purchased new villas from them',
#   'I love',
#   'qualiy',
#   'Very good morning sir please send me your family group',
#   'Advertisement',
#   'about a death a westfield shopping centre',
#   'yres very dgod',
#   'Just an advert over the radio',
#   'i like it very good service for everyone to use it',
#   'News from the financially press',
#   'It suits me',
#   'Great service',
#   'Ok',
#   'It’s a good company and has excellent service and products',
#   'happy',
#   'their constant upping of interest rates',
#   'Taking care of the aspects related to amazon',
#   'Happy',
#   'Ads on their health insurance cover',
#   'It is well_know brand for many years.',
#   "It's a good",
#   'Tv advertising   They are innovative company',
#   'how the government mistrusts it',
#   'Advertising around retirement villages',
#   'Trying to attract customers',
#   'I read about it',
#   'Just advertising on TV',
#   'Their yearly report',
#   'very',
#   'fnfdn  xdbx',
#   'I seen it on TV',
#   'Bay of Plenty Retirement Villages',
#   'commenting about emissions',
#   'advertisment online',
#   'How they are increasing the interest rates without being bothered about the financial well being of people and how things are hitting them hard with the interest rate rise',
#   'vehicle review online and in print magazines',
#   'I’ve seen a lot of ads which is why I decided to use it and I was very happy with the outcome',
#   'A television commercial advertising the companies products',
#   'high quality in services',
#   'Our company uses their products',
#   'I like it interseting.',
#   'Company meeting we got a briefing as to why management had selected Lenovo to resupply all company laptops. This was due to a great product and ongoing support and future updates.',
#   'Ad on tv for electric cars theme song is beautiful',
#   'increase in interest rates',
#   'Tesla owner bought Twitter',
#   'collins st falcons',
#   'I’ve seen the new models out on the market, through TV advertisements',
#   'ADVERTISING ON TV AND ON THE COMPUTER',
#   'I like it',
#   'Good news',
#   'Have seen some ads on TV',
#   'data breach',
#   'They raised interest rates in response to increasing inflation',
#   'naar',
#   'Ads and services',
#   'TV add I think',
#   'I have read their catalogue and seen their products in stores',
#   'Ad on TV',
#   'Advertisements on boards',
#   'The data breach',
#   'I am to madibank private',
#   'vhmhv f',
#   'severe data beach',
#   'Seen ad on TV',
#   'Product introdution',
#   'Amazing amazing',
#   'Additional features',
#   'TV advertising new vehicles',
#   'Just news headlines and advertisments',
#   'Their new Ford Ranger Advert on the internet is excellent would definitely consider buying one. We’ll thought, creative advertising',
#   "I support clients who live in different Summersets around Hawke's Bay.  I see what is going on and I sometimes have a chat with the staff.",
#   'App advertising',
#   'Computer was hacked and customer details gained in breach',
#   'They increased interest rates',
#   'very interesting',
#   'Advertisements for their new vehicles. Particulate the smart vehicles (Ie. Battery charged)',
#   'postive',
#   'sgsgfdgdf',
#   'Advertising for ebay',
#   'they will NOT look after customers concerning a MAJOR engine problem on a certain model',
#   'It has good quality.',
#   'How they have raised interest rates highly',
#   'VERY GOOD',
#   'picture',
#   'costo',
#   'I heard that their results were poor because they have been banned from some networks and countries owing to being an arm of the MSS',
#   'Some posts on social media about iconic buildings in Melbourne. Also have seen a billboard',
#   'Electric cars manufacturing',
#   'interest rate',
#   'Very good morning sir g sir please find the attached file is scanned image in PDF format hai to usne chek the attachment',
#   'sustainable activity',
#   'very fell.',
#   'good and reputable',
#   'Ad phone Samsung phone',
#   'is a reputable quality brand with fast application',
#   "Advertising about it's products and services",
#   'It was television advertising',
#   'CHETAYS',
#   'Advertising about living there',
#   'They are coming out with a new car',
#   'A Very good offer to buy a Samsung Mobile phone',
#   'Medibank Private has been hacked by Russian criminals, ransom was not paid so private customer personal details have been released.',
#   'Poor nursing conditions',
#   'Information technology and development of the day is best for you',
#   'Giant LEGO blocks.',
#   'gzdg',
#   'Bupa is one of the largest aged health care company in New Zealand.',
#   'They just finished another sub division and are now selling properties.',
#   'Ciber attack',
#   'A lot of yellow themed happy ads',
#   '4wd adds.',
#   'i heard it on Youtube',
#   'Email mailing list for Christmas stuff',
#   'Product promition.',
#   'I am to adirs',
#   'I feel it is very good if possible it is always the best product line that we have ever met or heard of.',
#   'Mars',
#   'Very nice and beautiful full survey this is the',
#   'I think it is so good.',
#   'Nothing',
#   'Good service',
#   'verry good',
#   'Tv advertisement',
#   "Can't remember details but have seen ads on tv",
#   'Very nice',
#   'It was an ad for Amazon prime showing all the action movies they have available',
#   'I feel the authentic.',
#   "I've seen TV advertising some of the benefits of living in a Summerset Retirement Village showcasing in particular the various social activities enjoyed by residents and offering glimpses of some of the communal amenities in the village.",
#   'It has a reputable service .',
#   'Okay I’ll stop by tomorrow to',
#   'quality very good',
#   'ongoing disputes with some countries re mines',
#   'They were hacked and private data was stolen.',
#   'THE BLOCK 2022 contestants all used bluescope to build  the big structure that now houses their living, kitchen,  dining, laundry & several more areas',
#   'is a big bank',
#   'great',
#   'How they are the best in what they do and they care about everyone',
#   'I have heard it',
#   'I think it is very interesting.',
#   'People using google to search for information to commit crimes/murder/suicide',
#   'Lenovo made a profit in the last 12 months',
#   'Ads in the Herald and on line',
#   'the catalogue for Friday deals',
#   'Seen ad on tv about them',
#   'BP Australasia very good',
#   'Provide housing projects in Sydney',
#   'as',
#   'To shop there',
#   'Roofing material',
#   'Data breach, ransom etc etc',
#   'Prestige and quality.',
#   'Not really sure',
#   'Very good morning sir g sir please find',
#   'ads very interesting',
#   'Better cars with good ratings',
#   'very quality',
#   'creation.',
#   'I read there post on instagram and my son lobe master lego on tv',
#   'high news and apps',
#   'cyber attact',
#   'Very good morning I am also thankful for your time and the conclusion',
#   'Adds about Ranger ute',
#   'I have heard in an article online Lenovo is releasing new products that will compete with top rating tech companies',
#   'quality',
#   'Ad for car sales   Advertising around local town   Advertising on internet ad',
#   'They invest in retirement homes',
#   "CAN'T REMEMBER",
#   'very nice',
#   'Well',
#   'Media',
#   'Yes, reports on cybersecurity efforts',
#   'about being hacked and threat to expose customers records - and refusing to pay ransome',
#   'Raising of interest rates',
#   'I feel very good.',
#   'it suits me',
#   'BCB',
#   'very good and quality',
#   'New revival creams ointments',
#   'I heard it on Youtube',
#   'Stolen Water in America',
#   'General advertising of their products',
#   'Info hack',
#   'reoutation',
#   'Test drive',
#   'the raising of interest rates and the debate around this',
#   'Promotions.',
#   'Heard it was a reputable company',
#   'Walked past the ship',
#   'cyber breech of their customers',
#   'Reading info regarding its current share price on stock market and why its so low also how it competes against arvida',
#   'Canstae Award for best health provider',
#   'miss',
#   'the hack',
#   'I have witnessed their work in an aged care facility  - it is appalling.',
#   'very nice for me and them',
#   'tv advertising wind farms',
#   'That they have really miss handled interest rates over the last two years',
#   "emails on products that I'm watching",
#   'People talking about tesla',
#   'cyber attacks',
#   'thrive',
#   'Tv show called Lego Masters has been a huge hit.  Large store at Robina Town Centre always looks bright, exciting and fun.',
#   'The data breach.',
#   'The battery in their cars blowing up. Also, the government wanting to gain access to shut peoples cars down.',
#   'data breech',
#   'Monitoring and raising interest rates to curb inflation',
#   'Receive textss from them nearly every day regarding products and services',
#   "it's one of the top ten investments",
#   'sdfsdfdss',
#   'very exciting',
#   'I was on their website last night',
#   'i have seen newspaper ads and ads instore when i last visited an athletes foot outlet',
#   'Regarding the data breach of their client information.',
#   'aykEEZ56@^',
#   'It was negative about failure to introduce a changed cash rate earlier',
#   'I heard about stockland on TV',
#   'I feel it is very good and I have read a lot of brand lines about it',
#   'They lost control of DATA',
#   'Very nice and nice and cute baby and beautiful is the best',
#   'OVHC',
#   'How good its latest models are',
#   'Advertising on tv and online'],
#  'AP_AW2_2': ['lots of ads about retirement living & the high standadrs of their properties',
#   "I've heard about them being cyber hacked and all their customer information has been hacked. I'm not with them now but used to be so have had my details exposed also.",
#   'advertisments',
#   'I have sen tv ads for new computers',
#   'TV  ads',
#   'Only TV advertising',
#   'Just a Tik tok',
#   'Marketing content',
#   'Increasing fees',
#   'Looked at having my mother there. Understaffed overpriced money grab. Sell sell sell no quality of care.',
#   'Very good.',
#   "The largest security breach of customers' personal data",
#   'Ads online',
#   'Mecca best brand in makeuo',
#   'Advertisements for their sales and new ways to shop',
#   'Reliable products',
#   'i like it',
#   'I feel very exciting',
#   'service product like the',
#   'Corrugated iron roof.',
#   'sggfdgdfg',
#   'They send me a email',
#   'Is a reputable brand.',
#   'Rate rises  Uncontrolled inflation  Expected future increases',
#   'Advertisements',
#   'Have seen advertising on television and national media',
#   'Very trust worthy and confident.',
#   'Sustainable Development',
#   'online tampering and web theft',
#   'from family that live there',
#   'free delivery ad on tv',
#   "Lots of news stories about their data breach and release of customer data on the web. They don't seem to have managed it overly well",
#   'I saw HCF on youtube',
#   'Social media',
#   'They recently got hacked.',
#   'Criticism of them as the least trusted news organisation in Australia',
#   'yjnrf mth',
#   'Catalogue',
#   'it is very gerat',
#   'From where I came from, products available in the nearby mini-mini-convenient store are just Unilever and P&G. Its just between the two. All I know, arguable or not, their shampoos,toothpastes and soaps are better than that of the other company.',
#   'products',
#   'Yes, i have',
#   'amazing',
#   'fgfdgdgfdg',
#   'Ads on TV',
#   'AMI signs with MTF Finance',
#   'Privacy breeches',
#   'new quantum computer',
#   'Merged with Big River in 2016',
#   'They are leader in information technology',
#   'Seen ads on tv',
#   'ADVERTIZING',
#   'Foxtel has signed new content contracts',
#   'I really enjoy',
#   'that had a data breach .a hacker has their customers information',
#   'Privacy and data breaches',
#   "It's been hacked",
#   'i like brand',
#   'freshness',
#   'products available using search engine',
#   'Electric Bicycle.',
#   'News about auditing increase',
#   'Tv adverts',
#   "it's very big",
#   'Ad',
#   "I hear a lot about the brand's advertisements",
#   'Discount specials on bed quilts & linen',
#   'about hacking and dreadful security issues',
#   'hrhdrd',
#   'Very nice and beautiful full',
#   'hacking',
#   'Customers data has been breached by hackers',
#   'Tv commercial',
#   'I visit their news site daily and they have positive reviews.',
#   'Having trouble obtaining staff - no surprises there as  care workers are at the bottom of the pay scale',
#   'Problems due to cyber attack & attempted extortion.',
#   'mazda new car brand',
#   'car models on tv',
#   'i heard it on social media',
#   'IAG New Zealand  IAG New Zealand is the largest general insurer in the country, trading under our brands AMI, State, NZI, NAC, Lumley and Lantern, as well as through our banking partners ASB, BNZ, Westpac and The Co-operative Bank. We employ over 3,500 people, insure more than two million New Zealanders and more than $680 billion of commercial and domestic assets.',
#   'News.com.AU',
#   'Sacking 10000 workers before Christmas',
#   'Flyers',
#   'Tv advertising about Legomasters',
#   'safe and high quality for clients',
#   'Can’t specifically remember but do remember hearing',
#   'BHP trying to market itself as a positive company - talking about changing from mining coal to instead mining minerals such as copper, which are essential in solar and electric vehicles etc',
#   'Just advertising from them',
#   "Medibank's offshoot AHM has been hacked",
#   'advertising their products on tv',
#   "Can't recall details. Ad on tv",
#   'they raised interest rates',
#   'Enjoy',
#   'you tube',
#   'Ad on tele',
#   'On the show the bock',
#   'I have seen and seen many ads from this brand',
#   'relative was in care. was very well cared for till death',
#   'Advertising on Facebook',
#   'email newsletters  with offers for components etc',
#   'Very nice and beautiful full survey this is',
#   'a tv ad',
#   'It is very great',
#   'it is pushing petrol-driven vehicles',
#   'Very nice and beautiful pics of the academic',
#   'received adv. pamphlets',
#   'Advertising Lego on tv',
#   'Car as on tv',
#   'As new insurance plan in market',
#   'Insurance for busy lives ad on tv',
#   'i like much',
#   'Reports as to countries banning them form involvement with 5g rollout and provision of telecommunications services due to close affiliation with Chinese Government',
#   'advertising their services on TV on demand',
#   'Their product is not selling real well and they have issues with their nursing homes.',
#   'Hacking news',
#   "I've seen their ads on tv and cinema screens",
#   'ON TV with regards to Ebay plus',
#   'General advertising',
#   'There are many device with modern techniques.',
#   'Interest rates up each month',
#   'modern',
#   'advertising flyer about Awatere apartments opening',
#   'Tv adds',
#   'Seen advertisement on a digital bill board advertising their newest brand, looks awesome',
#   'I read and listen to Scentre group very well',
#   'Just my insurance renewal',
#   'more promotions',
#   'ít so great',
#   'Not sure if it was on TV or online',
#   'I feel the quality.',
#   'It has good security.',
#   'A brand that is always aiming for moderrnity.',
#   'Advertisement on tv',
#   'Laptop prices, types',
#   "It's verlike",
#   'ok',
#   'Lego Masters Christmas special on TV',
#   'TV ADVERTISING FOR THEIR PRODUCTS.   YOUR WORTH IT ',
#   'It’s very good for me',
#   'advertising on television',
#   'Okay I’ll stop at',
#   'Bups service, caring about people',
#   'I have received direct e-mails and correspondence from Westfield as well as seeing advertising for Westfield when I have been out and about.',
#   'sd',
#   'quality good.',
#   'I have read it',
#   'nothing',
#   'i read on social media',
#   'is a famous brand, quality, reputation, fast application',
#   'Mining',
#   'I heard it on social media',
#   'I have just seen basic advertising of the company and of its working activities. Basic news Cover and stocks trades and acquisitions on report',
#   'They email me with current specials',
#   'Very good',
#   'Another rate increase',
#   'ads very important',
#   'I see it very quality.',
#   'fhfd',
#   'Interesting',
#   'good idea',
#   'rhdeh',
#   'beautiful very.',
#   'My workplace is currently doing business with Bhp',
#   'Advertising on the internet',
#   'Amazing',
#   'Article about how they run old age homes, very negative article.',
#   'I saw an article in the local paper with regards to the staff shortages they have having',
#   'Used Google on Internet',
#   'nvnv',
#   'I think I read somewhere about them potentially hsing drones for delivery. Also, just about how unethically they treat their workers. How much money they made during the pandemic.',
#   'I feel very useful',
#   'nissan nivara',
#   'Young drivers three times more likely to have their car stolen',
#   'its the frame work for the houses on  The Block ',
#   'Christmas photos',
#   'On app',
#   'is very great',
#   'Good',
#   'The issue in WA on all platforms',
#   'Medibank provides a range of services including health management and telehealth services for government and corporate customers, and the sale of travel, life and pet insurance products.',
#   'power bill',
#   'Increasing interest rates',
#   'Mostly things related to Elon musk on social media',
#   'yes i heard about it',
#   'About new products',
#   'like',
#   'sdfgdssdsdfsd',
#   'I read about the update to the i30N in a motoring column',
#   'Through ads from Facebook and instagram',
#   "It's good security.",
#   'Flyers in the paper and ads online',
#   'ANZ',
#   'advertising on tv, between programs.',
#   'Bupa very good',
#   'I am seen relating to costco',
#   "I've seen people using ACER computers.",
#   'new creations',
#   'I saw a commercial on tv about eBay',
#   'I have driven mazda vehicles',
#   "doctor's advice",
#   'Bupa ad on tv',
#   'Just the adverts on television',
#   'A brand that is always trusted and chosen by customers.',
#   'likely',
#   'gftmfg frn',
#   'Enjoy,truts',
#   'tv advert promoting its facilities as being friendly',
#   'Hacking personal information',
#   'REBEL SPORT IS A BIG BRANCH COMPANY',
#   'phone advertisement',
#   'you can get free delivery with a lot of the products they sell.',
#   'i likes acer',
#   "I've been involved in supplying products for construction of their buildings",
#   'very necessary',
#   'Advertising its electric cars. Supplying the batteries for the solar panel in Australia',
#   'Interest rates will be going up again',
#   'website',
#   'Second hand ford motor vehicle',
#   'HAPPY',
#   'Good commercial results',
#   'data breach of their clients',
#   'that they were hacked...',
#   'sponsership of wafl',
#   'email, tv add',
#   'Business went up to as pre-pandemic',
#   'i like them',
#   'technology company',
#   'safe and fun',
#   'Information about your self on the day of the world cup dekhe song',
#   'DAE',
#   'Parking issues at Tea Tree Plaza. Conflict with SA government over parking fees charged to customers, staff and hospital and obahn people. Closing parts of the car park at night to limit who uses their parking spaces.  re buying from them - actually buy products from the businesses that rent floor space from the organisation - do not deal with  Westfield directly.',
#   'good service',
#   'news',
#   'People on  news  that have issues with various ones',
#   'They look after the elderly',
#   'received emails from google about websites',
#   'Positive',
#   'Recent interest rate announcements',
#   'Tv and shopping centre',
#   'Newspaper and TV reports about the Company which is a positive report.',
#   'perfect quality',
#   'Add on TV about the company',
#   'I feel very usfeul',
#   'dsf',
#   "It's good quality.",
#   'i saw on tv that they raised the interest rates again. They are so awful and are killing australians',
#   'Very like.',
#   'a13 is crap',
#   'Ads on social media about them',
#   'cheap',
#   'The block show',
#   'That is car very color',
#   'They have great deals',
#   'Seen a commercial on youtube',
#   'positive',
#   'Just a sign outside one of their resthomes',
#   'The destruction of aboriginal sites',
#   'TV Advert',
#   'Information technology',
#   "It's pop ups when looking at various stuff on my mobile advertising its services and products",
#   'THE CURRENT HACKING SCANDAL OF COURSE.',
#   "it's so great",
#   'Customer disappointed that a product shes spent the year paying for is unavailable. Payments returned but no interest paid.',
#   'Store signage',
#   'I read and listen to Asus tek computer inc very well',
#   "it's so good",
#   'I know and visit several people in 4 Ryman villages',
#   'Medibank hacking',
#   'Tv advert for Kona',
#   'faster',
#   'Qualityful and productive products.',
#   'Information about your self comfort',
#   'TV commercial, Facebook commercials',
#   'Medibank private hacking issues',
#   'Advertisments',
#   'The terrible way they treat employees',
#   "Members' personal data have been hacked.",
#   'Have been searching their website for a new car',
#   'HCF will return some money to members prior to Christmas as during Covid less claims were made than usual',
#   'I saw the advertisement about this, I like the new product very much, and the advertisement is very creative and attractive.',
#   'Their new electric cars.',
#   'one in every two Australians depend on Huawei for their communications needs',
#   'Social media about new cars. Issues with the lack of quality of new cars',
#   'Insurance advertising on TV',
#   'Medibank scam',
#   'good quality',
#   'I go to the shopping centre every week.',
#   'moic',
#   'I am to hush puppies',
#   'Good deals',
#   'Very good morning ji',
#   'Data breach, they were hacked',
#   'no',
#   'Yes',
#   'General Advertising for their goods & services.',
#   'Were looking at selling their rest home business here and in Australia',
#   'I have seen the show called lego masters on tv .',
#   'have or',
#   'ppoTSL69&~',
#   'only it is a off soot of facebook to relief the heat',
#   'From colleagues at work and it was all positive',
#   'I just watch some ads on tv',
#   'I have seen ads for products across social platforms and/or youtube ads.',
#   'I am heard or seen',
#   'I feel the exciting.',
#   'Offering cash to join',
#   'credit.',
#   'I get emails from them every day and have seen their tv ads',
#   'moi',
#   'Information technology and services to be done',
#   'the internet security breach it had',
#   'Selling off some of their care homes, then going to sell entire NZ holdings, but unsure as any interested parties pulled out and no further interested (my be due to lack of government investment in aged care) but Bupa not commenting, refused to comment',
#   'Stocks prices in the news',
#   'service and product quality',
#   'Read policies',
#   'Advertising and online Google searches on other sites',
#   'That have plenty of shops open over Christmas',
#   'New models of cars and their features',
#   'E Mails relating to my policy with them',
#   'Good product I will support the product a lot.',
#   'how they are firing a lot of people',
#   'ctaIUZ63^!',
#   'The new for everest',
#   'eBay advertising their products and eBay Tuesdays on television',
#   'is a large online sales site',
#   'Promo on CX 5 in a article on line',
#   'Just something on the radio.',
#   'Advertisng in catalogues',
#   'Client Data hacked',
#   'that they raise or lower interest rates on mortgages',
#   'prices going up',
#   'masters lego xmas special',
#   'Just advertising on TV.',
#   'dsvsd ndfb',
#   'Issues with their seatbelts',
#   'Just TV advertising',
#   'Advertisements on tv and social media',
#   'fdgbfdgg',
#   'Strong growth in overseas av',
#   "The latest Galaxy mobile 'phone.",
#   'PRESTIGE COMPANY',
#   'New frontier project playform',
#   'THIS SERVICE IS GOOD I LOVE IT',
#   'Information technology it headache Manezer',
#   'sets interest rates',
#   'That is a generous and respectful health insurance',
#   'I find it very good.',
#   'TV and streaming ads, billboard outside BUPA facility',
#   'rhtg nfdn',
#   'Advertising in public areas',
#   'it is famous',
#   'Watch Lego master. Tv advertising. On the free magazines.',
#   'very likely',
#   'Advert on tv for eBay',
#   'It is very nice',
#   'All customers privacy got stolen',
#   "Tv ad about life at Bupa. Can't remember it exactly",
#   'Very develop',
#   'very great and develop',
#   'Chocolate advertising everywhere',
#   'Love my Hyundai car',
#   'Maybe I have seen about it.',
#   'very helpfyll',
#   'the security breach',
#   'I read and listen to unilever very well',
#   'aodBMS33^%',
#   'Very nice and beautiful full survey',
#   'Very nice day of the world cup dekhe song download in',
#   "It's a good time information",
#   'An advertisement in amagazine',
#   'cheap.',
#   'What do I have a question 🙋 I’m in a mood of a little',
#   'Love nothing',
#   'I am seen relaing to mars',
#   'my friend was telling me about how her father is in care at a bupa nursing home',
#   'Quality',
#   'how they are making it easy to setup remote workplaces and securely',
#   "It's very good",
#   'Very nice and beautiful',
#   'Very grateful',
#   'Very good morning sir ji and',
#   'I have only read about new products Dell is releasing into the market.',
#   'TV add',
#   'new building',
#   "They got hacked and alot of people's data is exposed to thrives now.  They didn't have data security.",
#   'Free power day',
#   'ads on TV for Ford cars',
#   'Shares, products on TV',
#   "Mention of it alongside other banks in a bank comparison article online. Can't remember anything specific.",
#   'Very develop and friendly',
#   'It is very nice and interesting',
#   'financial difficulties, bailed out by CBA',
#   "Mainly advertisements for its Computers, Printers and like accessories.Hewlett-Packard is a large US company, I have owned HP PC's in the past but now use Acers mainly.",
#   'Only advertisements online',
#   'TV ad - but often ads do not reflect reality',
#   'I heard image promotion',
#   'Good quality',
#   'Their new spring linen collection on face book',
#   'e',
#   'moder',
#   'TV ads    Renewal of two policies with AMI',
#   'trust.',
#   'Put up interest rates',
#   "i don't know",
#   'hacked',
#   'Bluescope steel profits at record levels',
# ...
#   'Citizens bank of pennsylvania'],
#  'Q_N_10771_005_98_other': ["I'm not sure",
#   'Citizen Bank Park',
#   'Bank',
#   'CITIZENS BANK',
#   'CIT Bank'],
#  'Q_N_1109_002A_7': [1.0],
#  'Q_N_1109_002A_98_other': ['Living near a Southwest Hub.',
#   'used 2x to fly',
#   'Past use',
#   'Flown on in past',
#   'Flew in the past. Cheap but uncomfortable',
#   'emails',
#   'I took a flight a couple of years ago.',
#   'Previous flights'],
#  'Q_N_1109_002_9': [1.0],
#  'Q_N_1109_002_98_other': ['Flown it a lot when I traveled for business',
#   'Use to travel',
#   'I have flown with Southwest about 5 yrs ago',
#   'flown before',
#   'Used their service',
#   'it is the best option from my home airport',
#   'ID REMEMBER',
#   'use of their product',
#   'Google Flights',
#   'Low prices',
#   'flying with them',
#   'previous experience',
#   'Rewards program',
#   'Personal travel experience',
#   'Travel',
#   'prior experience with them'],
#  'Q_N_1109_003A_8_other': ['Open seating', 'pricing policy'],
#  'Q_N_1109_005A_10': [2.0, 3.0],
#  'Q_N_1109_005A_7': [1.0],
#  'Q_N_1109_005A_8': [1.0],
#  'Q_N_1109_005_7': [3.0],
#  'Q_N_11613_003A_1': [99.0],
#  'Q_N_11655_001A_1': [42.0, 44.0, 55.0, 25.0, 60.0, 62.0],
#  'Q_N_11655_001_1': [12.0, 45.0, 14.0, 47.0, 27.0],
#  'Q_N_11655_002A_1': [99.0],
#  'Q_N_11655_003A_1': [7.0],
#  'Q_N_11655_003A_1_98_other': ['Brighthealth',
#   'Anthem',
#   'BCBS Federal',
#   'devoted',
#   'EmblemHealth',
#   'Health First',
#   'Oscar',
#   'WellCare',
#   'Blue Shield of California'],
#  'Q_N_11655_003_1_98_other': ['Brighthealth',
#   'Hillsborough county healthcare',
#   "I don't know",
#   'Bright Health',
#   'The Health Plan',
#   'wellcare',
#   'Optimum',
#   'Tricare',
#   'Blie',
#   'Priority Health',
#   'Vsp',
#   'BaycarePlus',
#   'Medicare',
#   'Devoted Health'],
#  'Q_N_11939_003A_1': [99.0],
#  'Q_N_1248_003_2': [1.0],
#  'Q_N_1248_003_3': [1.0],
#  'Q_N_153_003A_2': [1.0],
#  'Q_N_1649_001A_1': [1.0],
#  'Q_N_1649_005A_5': [1.0],
#  'Q_N_1649_005A_6': [1.0],
#  'Q_N_1649_005_5': [1.0],
#  'Q_N_3603_002A_98_other': ['Supports national charities',
#   'Give more winnings to customers',
#   'end food waste feed the hungry with leftovers',
#   'COVID-19'],
#  'Q_N_3603_002_98_other': ["Hopefully MGM puts its financial goal ahead of phony ESG ratings.  Don't play the ESG game. Be a good corporate citizen without playing to this scam program.",
#   'Not sure',
#   'Unknown',
#   'Produce a profit'],
#  'Q_N_3669_001A_5': [1.0],
#  'Q_N_3669_001A_7': [1.0],
#  'Q_N_3669_004A_99': [1.0],
#  'Q_N_3669_005A_1': [1.0],
#  'Q_N_3669_005A_4': [1.0],
#  'Q_N_3669_005_1': [1.0],
#  'Q_N_3669_005_4': [1.0],
#  'Q_N_4886_006A_1': [1.0],
#  'Q_N_4886_006A_5': [1.0],
#  'Q_N_5021_002A_1_98_other': ['previous investor',
#   'Previously worked in the financial services industry',
#   'I invested my IRA in LPL years ago',
#   'workED in financial',
#   'Spouse worked for lpl'],
#  'Q_N_5021_002_1_98_other': ['my employer works with them',
#   'Have an IRA through them',
#   'my financial advisor invest in LPL for me',
#   'None of these',
#   'Recall seeing the name',
#   'I do business with LPL',
#   'The company I work for has investments with them',
#   'I use to invest with LPL Financial and I feel I was ripped-off because of my lack of knowledge. I have never received any gains from my investment; it went all to LPL Financial.'],
#  'Q_N_5021_004_98_other': ['I have a full service advisor'],
#  'Q_N_5075_002A_1': [6.0],
#  'Q_N_5157_002A_98_other': ['Strategic Intelligence Consulting',
#   'Applications',
#   'Scientific',
#   'Military',
#   'Space program',
#   'Consulting'],
#  'Q_N_5157_002_98_other': ['Psyops',
#   'Government contracts',
#   'Create ai machines',
#   'training',
#   'Government contractor',
#   'Consulting and Govt Contracting'],
#  'Q_N_5603_004Ax1_98_other': ['Miscellaneous',
#   'None',
#   'Home Goods',
#   'Flea Meds',
#   'Trade Joe',
#   'PetSmart',
#   'Chewy.com'],
#  'Q_N_5603_004Ax2_11_7': [1.0],
#  'Q_N_5603_004Ax2_98_other': ['Smart and Final',
#   'none',
#   'Pretty Litter',
#   'Winco',
#   'Other',
#   'Walgreens',
#   'Costco'],
#  'Q_N_5603_004x1_98_other': ['Publix',
#   'Tractor supply',
#   'Family members',
#   'Dr. Marty',
#   'Franklin aquarium',
#   'Get from my son',
#   'Any others',
#   'J and M Pet Store',
#   'walmart',
#   'Family dollar',
#   'big lot',
#   'Meijers',
#   'He was the',
#   'Order catalog',
#   'Per food express'],
#  'Q_N_5603_004x2_98_other': ['Tractor supply',
#   'Commissary',
#   'Chewey',
#   'Franklin aquarium',
#   'amazon',
#   'Aldi',
#   'Gas station',
#   'ShopRite',
#   'He was',
#   'walmart',
#   'Grocery store',
#   'Dollar tree',
#   'Order catalog',
#   'Military Commissary'],
#  'Q_N_5603_005A_98_other': ['Variety for dog with food allergies',
#   'I DONT KNOW',
#   'Makes human grade, raw food',
#   'Do not have pets',
#   'Recycle beyond packaging (toys, leashes)',
#   'your survey is broken'],
#  'Q_N_5603_005_98_other': ['Specials',
#   "doesn't source out to China",
#   'None of these',
#   'Disclosed meat source',
#   'n/a',
#   'nothing',
#   'Make objects capable to withstand the use of the animals that need it.'],
#  'Q_N_707_001A_13': [1.0],
#  'Q_N_707_001A_18': [1.0],
#  'Q_N_7966_001A_1': [16.0, 11.0],
#  'Q_N_7966_001_1': [8.0],
#  'Q_N_7966_002A_1': [6.0],
#  'Q_N_7966_003A_1': [11.0, 14.0],
#  'Q_N_7966_003_1': [16.0],
#  'Q_OE_10771_003A_1': ['Better interest rates with loans. No hidden fees, better interest in savings',
#   'I hope to be able to see a change with mobile apps and pay.',
#   'I would like the bigger banks to treat their customers as well as the local banks do, and reduce their ridiculous fees.',
#   'No fees for day to day banking',
#   'More automation; customer focused service',
#   'Lower interest rates.',
#   'cannot think of any.',
#   'more user friendly apps and transparent communication',
#   'Bigger return on your money.',
#   'Higher yield on investment and less fee charges. I am worried they will hurt business by fee inflation',
#   'N/a',
#   'More savings options and more cash free options',
#   'Better security for their customers.',
#   'Being that my mother had a bad experience with citizens bank would expect better customer service and empathy',
#   'quality',
#   'Better rates for customers',
#   'Better communication…touting # changed but they didn’t inform me, hence my pension check stopped getting deposited!   That was a problem and poor customer service on their end!',
#   'Better technology',
#   'Just fair and equal opportunity for all who are looking for a positive banking experience.',
#   'Higher interest on savings and checking',
#   'Better interest rates',
#   'More ways to help people in poverty.',
#   '-Way to communicate more to people regarding better services and opportunities. Having more business internationally.',
#   'The first thing that comes to my mind is that they have a high banking interest rates on accounts',
#   'Don’t know what else there is. Already can do everything online.',
#   'Credit repair options',
#   'I think more of them should get customer feedback on what products/services they want and do it. I also think AI needs to be used more effectively to benefit their customers.'],
#  'Q_OE_10771_003_1': ['More community outreach and education on investments.',
#   'Fairness',
#   'I expect them to offer the latest technology for their customers to use, while making sure their information is completely protected.',
#   'More trendy actions. We did stuff for Ukrainian but what about other issues happening ?',
#   "They are already very innovative and keep up with the new trends so I'm sure that they will be among the 1st to continue to do so",
#   'Treasury Management solutions.  Same day ach, real time payments',
#   'Transpency',
#   'More privacy protection',
#   'Secure transactions',
#   'Instant transfers',
#   'More with environmental impacts',
#   'Help saving',
#   'CD enhancements',
#   'More credit card offers with rewards',
#   'Providing as best accurate information about future inveestments',
#   'Lower their overhead and stop charging such high fees',
#   'Better interest rate',
#   "AN INDUSTRY WHERE THEY TRY TO REMAIN FAIR AND JUST WHEN DEALING WITH CUSTOMER'S FINANCES",
#   'Better rates and security',
#   "Improve the industry's security.",
#   'I hope to see insurance completely overhauled as it is a vastly corrupt system that adds unnecessary financial burdens to the working class.',
#   'Ease if investing',
#   'I would hope to see higher interest rates.  I’d actually use a bank if the they were much higher than they are now. Interest rates have been very very low for a very long time. With inflation going up times are hard and banks aren’t hurting for money. Ex. If I put $100 in the bank, in one year it will draw hardly any interest. I would hope to see it draw at least $25 in a year.',
#   'Big investing',
#   'Keep costs down for custamers',
#   'I hope they start being truly concerned about sustainability and equity',
#   'I hope to see more cryptocurrency',
#   'Higher interest rates',
#   'To help everybody out don’t know how to invest their money or an app to help',
#   'That I could get a better saving rate which is related to economy I know.   More understanding',
#   'Great communication',
#   'More personalized one on one involvement in investing and maybe vrabonds?'],
#  'Q_OE_2828_011A_1': ['veerry good',
#   'great',
#   'yes',
#   'Their oil products for my companies use.',
#   'yes because have a great deal for me',
#   'Engine oil',
#   'Very good morning sir ji time to explore new technology',
#   'Oil',
#   'Energy purchasing for alternatives',
#   'interestig',
#   'tutela ,, its so better service',
#   'Nothing much comes to mind.',
#   'Cox density advice and clarity testing',
#   'Friendly',
#   'its very good',
#   'natural gas',
#   'fgdfgdfgdfgdf',
#   'Attractive',
#   'A petronas polo tee',
#   'i like so much',
#   "Disney Infinity will you be able to do family different things. I could use all of their products and they're very cool. You have a lot of really cool down her things. I really agree with your services.",
#   'Read and share a lot of news of PETRONAS.',
#   'oil for my cars',
#   'No comment',
#   'good and like this brand',
#   'their gas, oil products are very good',
#   'I like'],
#  'Q_OE_2828_011_1': ['oil',
#   'I almost use all product or services.',
#   'House hold products',
#   'customer service',
#   'Refilling stations and oil products.',
#   'I love it',
#   'very good brand',
#   'ITS VERY GOOD.',
#   'I find it ok.',
#   'it is very good and reliable',
#   'is very good',
#   'no',
#   'I have used all of them in a variety of capacities.',
#   'It has good services',
#   "oil i'm buying.good service..",
#   'The first thing that came out',
#   'Its good and i liked it so much',
#   'Interesting',
#   'dfdssdsdsffds',
#   'The products services I have used is energy and gas.',
#   'very interesting and more',
#   'It has a reputable service',
#   'I had bought oil for a motorcycle I own however was unable to use the product as it was incompatible with my vehicle.',
#   'I used the energy of the Petronas.',
#   'Good deal and prompt',
#   'Used a product that was ordered by my company',
#   'O&G brands',
#   'its very good',
#   'heating and electrical power',
#   'fuel',
#   'all thing its very good',
#   'It is so likely for me',
#   'Gas products',
#   'i like them',
#   'I really want it.',
#   'Attractive',
#   'Distinctio Incidunt',
#   "It's extremely good and excited",
#   'I didn’t personally used it, one of my family members used the oil/gas for her car.',
#   'Petronas syntium engine Oil',
#   'Mainly Fuel products',
#   'clothes',
#   "I don't know",
#   'Somewhere along the line I must have purchased gasoline they were involved in producing at some point along the .line.',
#   'I have clothes related to patronas. I brought them while going shopping. They are a comfortable fit.',
#   'gdfg',
#   'it was very good',
#   'Just some kind of petroleum products.',
#   'Exciting'],
#  'Q_OE_5240_005A_1': ['The football play Gront is trying to become a USAA member but he is not eligible',
#   'I had a friend that served in the military that used USAS that had good rates but that was solely because he was in the military.',
#   "So add on TV that says it's only for military service members and their families",
#   'The adds seem very postive',
#   'They have good insurance',
#   'A USAA commercial showing what they offer',
#   "Though my Dad served he wasn't a member of USAA, probably because it came into being long after he'd served and he didn't know about it. Now that I know about USAA, his children can't join because USAA doesn't allow posthumous joining.",
#   'Good adds',
#   'Affordability',
#   'Their TV spots',
#   'They help service members and their families. My husband is a veteran.',
#   'Just commercials that have Gronk in them',
#   'I spoke with an agent who didn’t want to take time to answer my husband’s questions that he asking her. She Kept trying to get him off the phone and call back tomorrow.',
#   'USAA has been there for members in the Hampton Roads area during the recent storms that went through the here.',
#   'The advertisements make it clear that USAA serves our veterans and active military.',
#   'like',
#   'They are working to improve the lives of service personnel and veterans',
#   'They are there when you need them.',
#   'How they help military families with all their needs. Help invest for a secure future for yourself and children',
#   'Their AML program is beyond ineffective and they were fined millions of dollars',
#   'Commercial on TV on how USAA supports military people.',
#   'A commercial on TV with Gronkowski',
#   "It's a good company if you are a veteran or active duty"],
#  'Q_OE_5240_005_1': ['that they will serve all service members',
#   'I have family who are members of USAA and they always have a positive attitude about it when talked about.',
#   'My daughter was in a no fault accident and the person who hit her has USAA insurance.  The accident was over 7 months ago and the claim is still not settled. USAA has been a nightmare, they did body work on the car before it was mechanically checked out.  USAA is saying they are only responsible for the bodywork, meanwhile the car is totaled. Now my daughter is going to put a claim through her insurance company and then the 2 companies will probably have to work it out or there will be a lawsuit. The USAA representatives my daughter and her husband had to deal with were not helpful or knowledgeable.  It was not until my daughter went on Facebook and wrote a bad review did she hear from other people who have had similar experiences with USAA.  Next my daughter will go to NBC news.',
#   "I have seen ads and things about how USAA supports the military and their families. I respect the military and I think it's important to support them. USAA appears to be committed to supporting the military.",
#   'It mentioned USAA was for military and their families.',
#   'Radio ad that USAA serves those who have served their country.',
#   'Friend complimentary of the company',
#   'A commercial very good',
#   'Just a regular TV ad',
#   'I saw a commercial emphasize USAA support of Military Servicemen.',
#   'That they offer help to people who was in the Military',
#   'They help protect you and your family',
#   'I think if you have served in the military they are an excellent company to use. I am not eligible.',
#   'Active duty member talking about how much he enjoys USAA.',
#   'A friend and I were talking about the cost of car insurance a few weeks ago.  I told her the price of insurance was just going beyond means.  She said,” she had insurance with USSA and her insurance was a lot cheaper than a lot of insurance companies.',
#   'They serve all veterans regardless of rank.',
#   "It was a TV ad and I liked the message but don't remember what it was.",
#   "I saw an ad for this brand via TV but I don't recall the exact details however it was something positive.",
#   'Television advertisements during NFL games.',
#   'It was a commercial describing what USAA offered as benefits and this intrigued me enough that I searched for their product online.',
#   'That they are an official sponsor of NFL football   NOT impressed with that',
#   'They are a good company for veterans',
#   'People using this product according to the news on USAA.',
#   'Tv ad seems positive',
#   'Advertisement and job offerings on linkedin']}

# %%
df_dtype_diff
# Out:
# Empty DataFrame
# Columns: [Column_Name, Current_Dtype, Previous_Dtype]
# Index: []

# %%
df_cur_missing_val_perc
# Out:
#              Column_Name  Missing_Percent
# 0              AGEGENDER         0.105180
# 1                AGE_ORI         0.093003
# 2              APAC_TOP1         0.418960
# 3              APAC_TOP2         0.463866
# 4               AP_AW1_1         0.992031
# 5               AP_AW1_2         0.992912
# 6               AP_AW2_1         0.998548
# 7               AP_AW2_2         0.998720
# 8            AP_AW2_99_1         0.998375
# 9            AP_AW2_99_2         0.998566
# 10              AP_AW3_1         0.998378
# 11              AP_AW3_2         0.998566
# 12         AP_EMPLOYMENT         0.991298
# 13         AP_INCOME_ADD         0.999230
# 14    AP_IND_REP1_198001         0.999132
# 15    AP_IND_REP1_198002         0.999135
# 16    AP_IND_REP1_198003         0.999137
# 17    AP_IND_REP1_198004         0.999135
# 18    AP_IND_REP1_198005         0.999129
# 19    AP_IND_REP1_198006         0.999132
# 20    AP_IND_REP1_198007         0.999135
# 21    AP_IND_REP1_198008         0.999135
# 22    AP_IND_REP1_198009         0.999132
# 23    AP_IND_REP1_198010         0.999132
# 24    AP_IND_REP1_198011         0.999132
# 25    AP_IND_REP1_198012         0.999129
# 26    AP_IND_REP1_198013         0.999132
# 27    AP_IND_REP1_198014         0.999135
# 28    AP_IND_REP1_198015         0.999135
# 29    AP_IND_REP1_198016         0.999135
# ...                  ...              ...
# 9540  S105Fielded_274380         0.990172
# 9541  S105Fielded_274381         0.996382
# 9542  S105Fielded_274382         0.995891
# 9543  S105Fielded_274383         0.979849
# 9544  S105Fielded_274384         0.985954
# 9545  S105Fielded_274385         0.967693
# 9546  S105Fielded_274387         0.977558
# 9547  S105Fielded_274388         0.985747
# 9548  S105Fielded_274389         0.956023
# 9549  S105Fielded_274390         0.975792
# 9550  S105Fielded_274391         0.982418
# 9551  S105Fielded_274392         0.952896
# 9552  S105Fielded_274393         0.987539
# 9553  S105Fielded_274394         0.987974
# 9554  S105Fielded_274395         0.986321
# 9555  S105Fielded_274396         0.993865
# 9556  S105Fielded_274397         0.986801
# 9557  S105Fielded_274398         0.982267
# 9558  S105Fielded_274399         0.986273
# 9559  S105Fielded_274401         0.997276
# 9560  S105Fielded_274402         0.999209
# 9561  S105Fielded_274403         0.953607
# 9562  S105Fielded_274404         0.994765
# 9563  S105Fielded_274405         0.983135
# 9564  S105Fielded_274406         0.970326
# 9565  S105Fielded_274408         0.959118
# 9566  S105Fielded_274414         0.987526
# 9567  S105Fielded_274419         0.968733
# 9568     SOCIALMEDIA_INF         0.999270
# 9569   SOCIALMEDIA_INF_A         0.999480
#
# [9570 rows x 2 columns]
